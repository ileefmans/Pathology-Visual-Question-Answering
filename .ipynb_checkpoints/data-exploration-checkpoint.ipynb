# %%
import os
from PIL import Image                       # package to manipulate and import images   
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import torch                                # package for deeplearning
from torch import nn
from torch.utils.data import DataLoader     # pytorch dataloader for easily loading minibatches during training
import torchvision                          # package for using images in deeplearning (computer vision)

from dataset import train_dataset, path_dict           # script for creating custom dataset

from preprocess import image_process

from nlp_preprocess import text_process
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Exploring the Data (Images)
# ### Convert single image to tensor and plot tensor

# %%
image = Image.open('/Users/ianleefmans/Desktop/data/train/part2/part2_images/11/218.jpg') ### image path on local device

# %%
image.getpalette # images are CMYK instead of RGB
# Out:
# <bound method Image.getpalette of <PIL.Image.Image image mode=RGB size=707x594 at 0x1A232B8910>>

# %%
image.show() # view image

# %%
# to convert from CMYK to RGB
if image.mode != 'RGB':
    image = image.convert('RGB')
    
image.show()

# %%
transform = torchvision.transforms.ToTensor() # create transform that changes image to tensor

# %%
image = transform(image) # transform image to tensor

# %%
image.size() # view image-tensor dimensions, there are 3 channels now (RGB) and the image 
             # is 400 pixels by 335 pixels
# Out:
# torch.Size([3, 228, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(image))   # plot image-tensor 
                                                                    #(note the same as origional image)

# %% [markdown]
# # Train Dataset Class
# ### Changing images to tensors and create dataloader
# Class has been created created. Here are the outstanding issues:
#
#   1) add option for varying image size (probably not neccessary)
#   2) need to add captions if they can be accessed

# %% [markdown]
# #### Below is used for testing:

# %%
#CREATE TRAIN DATASET CLASS

# Define arguments for train_dataset class
annotation_path = '/Users/ianleefmans/Desktop/data/train/part1/part1_2.json'
path = '/Users/ianleefmans/Desktop/data/train'
index_dict = path_dict(path)


#annotation = pd.read_json(annotation_path)

#create trainset
train_set = train_dataset(annotation_path, index_dict, img_dir = path, 
                          transform = torchvision.transforms.ToTensor())

# %%
annotation.Questions
# Out:
# 0        What are positively charged,  thus allowing th...
# 1                    How are the histone subunits charged?
# 2        Are the histone subunits positively charged,  ...
# 3         Where are liver stem cells (oval cells) located?
# 4        What are stained here with an immunohistochemi...
#                                ...
# 32794                                       Where is this?
# 32795                           What does this image show?
# 32796    Does this image show polyarteritis nodosa, kid...
# 32797    Does cytomegaly show polyarteritis nodosa, kid...
# 32798                                       Where is this?
# Name: Questions, Length: 32799, dtype: object

# %%
cln_txt = text_process(annotation.Questions)
text = cln_txt.pd_col_to_list()
text
# Out:
# ['What are positively charged,  thus allowing the compaction of the negatively charged DNA?',
#  'How are the histone subunits charged?',
#  'Are the histone subunits positively charged,  thus allowing the compaction of the negatively charged DNA?',
#  'Where are liver stem cells (oval cells) located?',
#  'What are stained here with an immunohistochemical stain for cytokeratin 7?',
#  'What are bile duct cells and canals of Hering stained here with for cytokeratin 7?',
#  'Are bile duct cells and canals of Hering stained here with an immunohistochemical stain for cytokeratin 7?',
#  'What are illustrated?',
#  'Are the principal cellular alterations that characterize reversible cell injury and necrosis illustrated?',
#  'Are methylation of particular histone residues illustrated?',
#  'What is considered to culminate in necrosis if the injurious stimulus is not removed, by convention?',
#  'How is reversible injury considered to do if the injurious stimulus is not removed, by convention?',
#  'Is reversible injury considered to culminate in necrosis if the injurious stimulus is not removed by convention?',
#  'Did early (reversible) ischemic injury increase eosinophilia of cytoplasm,  and swelling of occasional cells?',
#  'What is showing increased eosinophilia of cytoplasm,  and swelling of occasional cells?',
#  'What does ischemic injury show?',
#  'Does early ischemic injury show surface blebs, increase eosinophilia of cytoplasm, and swelling of occasional cells?',
#  'Do necrotic cells show preserved outlines with loss of nuclei, and an inflammatory infiltrate is present (difficult to discern at this magnification)?',
#  'Are the preserved outlines with loss of nuclei?',
#  'What show preserved outlines with loss of nuclei?',
#  'Do the necrotic cells show preserved outlines with loss of nuclei?',
#  'Do skin stem cells show preserved outlines with loss of nuclei?',
#  'What shows dissolution of the tissue?',
#  'What does an infarct in the brain show of the tissue?',
#  'Does an infarct in the brain show dissolution of the tissue?',
#  'Does preserved show dissolution of the tissue?',
#  'What represent foci of fat necrosis with calcium soap formation at sites of lipid breakdown in the mesentery?',
#  'Where do areas of white chalky deposits represent foci of fat necrosis with calcium soap formation?',
#  'What do the areas of white chalky deposits represent?',
#  'How do the areas of white chalky deposits represent foci of fat necrosis?',
#  'Do the areas of white chalky deposits represent foci of fat necrosis with calcium soap formation at sites of lipid breakdown in the mesentery?',
#  'Do the histone subunits represent foci of fat necrosis with calcium soap formation at sites of lipid breakdown in the mesentery?',
#  'What shows a circumferential bright pink area of necrosis with protein deposition and inflammation?',
#  'What does the wall of the artery show with protein deposition and inflammation?',
#  'How does the wall of the artery show a circumferential bright pink area of necrosis?',
#  'Does the wall of the artery show a circumferential bright pink area of necrosis with protein deposition and inflammation?',
#  'What are illustrated?',
#  'Are the cellular alterations in apoptosis illustrated?',
#  'Are methylation of particular histone residues illustrated?',
#  'What are shown?',
#  'Are apoptotic cells in colonic epithelium shown?',
#  'Are the areas of white chalky deposits shown?',
#  'What was removed for postpartum bleeding?',
#  'What was a gravid uterus removed for?',
#  'Was a gravid uterus removed for postpartum bleeding?',
#  'Was the injurious stimulus removed for postpartum bleeding?',
#  'What is ischemia?',
#  'What is the cause of reversible injury?',
#  'What is hypertrophy?',
#  'Is the cellular adaptation depicted here hypertrophy?',
#  'Is there an infarct in the brain hypertrophy?',
#  'What is ischemic coagulative necrosis?',
#  'What is the irreversible injury?',
#  'Is the irreversible injury ischemic coagulative necrosis?',
#  'What is thicker than 2 cm (normal,  1-1.5 cm) in the example of myocardial hypertrophy lower left?',
#  'How many cm (normal,  1-1.5 cm) is the left ventricular wall thicker than in the example of myocardial hypertrophy lower left?',
#  'Is the left ventricular wall thicker than 2 cm (normal,  1-1.5 cm) in the example of myocardial hypertrophy lower left?',
#  'Is reversible injury thicker than 2 cm normal,  1-1.5 cm in the example of myocardial hypertrophy lower left?',
#  'What shows functional effects without any gross or light microscopic changes,  or reversible changes such as cellular swelling and fatty change?',
#  'Does reversibly injured myocardium show functional effects without any gross or light microscopic changes,  or reversible changes such as cellular swelling and fatty change?',
#  'Does an infarct in the brain show functional effects without any gross or light microscopic changes,  or reversible changes such as cellular swelling and fatty change (shown here)?',
#  'What represents an acute myocardial infarction in the specimen showing necrosis?',
#  'What does the transmural light area in the posterolateral left ventricle represent in the specimen showing necrosis?',
#  'Does the transmural light area in the posterolateral left ventricle represent an acute myocardial infarction in the specimen showing necrosis?',
#  'Does reversible injury represent an acute myocardial infarction in the specimen showing necrosis?',
#  'How many transverse sections of myocardium were stained with triphenyltetra-zolium chloride,  an enzyme substrate that colors viable myocardium magenta?',
#  'What were stained with triphenyltetra-zolium chloride,  an enzyme substrate that colors viable myocardium magenta?',
#  'What were all three transverse sections of myocardium stained with?',
#  'Were all three transverse sections of myocardium stained with triphenyltetra-zolium chloride,  an enzyme substrate that colors viable myocardium magenta?',
#  'What is due to enzyme loss after cell death?',
#  'Is failure to stain due to enzyme loss after cell death?',
#  'When is failure to stain due to enzyme loss?',
#  'Is atrophy seen in the brain?',
#  'What is caused by aging and reduced blood supply?',
#  'What of the brain is caused by aging?',
#  'Is atrophy of the brain caused by aging and reduced blood supply?',
#  'Is reversible injury caused by aging and reduced blood supply?',
#  'What have been stripped from the bottom half of each specimen to show the surface of the brain?',
#  'What have the meninges been stripped from?',
#  'Have the meninges been stripped from the bottom half of each specimen to show the surface of the brain?',
#  'Have the necrotic cells been stripped from the bottom half of each specimen to show the surface of the brain?',
#  'What is called the Prussian blue reaction?',
#  'What is shown by a special staining process called the Prussian blue reaction?',
#  'Are iron deposits shown by a special staining process call the Prussian blue reaction?',
#  'What show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'What do the photomicrographs show in the myocardium after ischemic necrosis infarction?',
#  'Do the photomicrographs show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'Do apoptotic cells in colonic epithelium show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'When do the photomicrographs show an inflammatory reaction in the myocardium ?',
#  'What show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'Where do the photomicrographs show an inflammatory reaction after ischemic necrosis infarction?',
#  'When do the photomicrographs show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'What do the photomicrographs show in the myocardium after ischemic necrosis infarction?',
#  'Do the photomicrographs show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'Do the meninges show an inflammatory reaction in the myocardium after ischemic necrosis infarction?',
#  'When do the photomicrographs show an inflammatory reaction in the myocardium ?',
#  'What have lost their nuclei?',
#  'Whose nuclei have been lost?',
#  'Two have lost whose nuclei ?',
#  'Two have lost whose nuclei ?',
#  'What stained red and cytoplasm green?',
#  'Are healthy neutrophils with nuclei stain red and cytoplasm green?',
#  'Did the areas of white chalky deposits stain red and cytoplasm green?',
#  'Two have lost whose nuclei ?',
#  'What is separated from the dermis by a focal collection of serous effusion?',
#  'What does the low-power view of a cross section of a skin blister show?',
#  'How does low-power view of a cross section of a skin blister show the epidermis separated from the dermis?',
#  'Is low-power view of a cross section of a skin blister showing the epidermis separated from the dermis by a focal collection of serous effusion?',
#  'Is the irreversible injury separated from the dermis by a focal collection of serous effusion?',
#  'When are the majority of tissue macrophages derived from hematopoietic precursors?',
#  'When are the majority of tissue macrophages derived from hematopoietic precursors?',
#  'When are the majority of tissue macrophages derived from hematopoietic precursors?',
#  'What is surrounded by multiple multinucleate giant cells,  epithelioid cells,  and lymphocytes?',
#  'What does typical tuberculous granuloma show?',
#  'What is an area of central necrosis surrounded by?',
#  'Dose typical tuberculous granuloma show an area of central necrosis surrounded by multiple multinucleate giant cells,  epithelioid cells,  and lymphocytes?',
#  'Is an area of central necrosis surrounded by multiple multinucleate giant cells,  epithelioid cells,  and lymphocytes?',
#  'What is stained blue by the trichrome stain?',
#  'Is Collagen stained blue by the trichrome stain?',
#  'Is the injurious stimulus stained blue by the trichrome stain?',
#  'What is the major initiator of coagulation?',
#  'What is tissue factor, in vivo?',
#  'Is tissue factor the major initiator of coagulation,  which is amplified by feedback loops involving thrombin in vivo?',
#  'Is the major initiator of coagulation amplified by feedback loops involving thrombin?',
#  'What are inactive factors?',
#  'Are the red polypeptides inactive factors?',
#  'Are all three transverse sections of myocardium inactive factors?',
#  'What color are the active factors?',
#  'Are the dark green polypeptides active factors?',
#  'What correspond to cofactors?',
#  'What do the light green polypeptides correspond to?',
#  'Do the light green polypeptides correspond to cofactors?',
#  'Do the necrotic cells correspond to cofactors?',
#  'What consists of a protease, a substrate, and a reaction accelerator assembled on a platelet phospholipid surface?',
#  'What does the initial reaction complex consist of?',
#  'Does the initial reaction complex consist of a protease, a substrate, and a reaction accelerator assembled on a platelet phospholipid surface?',
#  'Does atrophy of the brain consist of a protease assembled on a platelet phospholipid surface?',
#  'What overlies white fibrous scar?',
#  'What does thrombus in the left and right ventricular apices overlie?',
#  'Does thrombus in the left and right ventricular apices overlie white fibrous scar?',
#  'Did the areas of white chalky deposits overlie white fibrous scar?',
#  'What are super-imposed on advanced atherosclerotic lesions of the more proximal aorta (left side of photograph)?',
#  'Are numerous friable mural thrombi super-imposed on advanced atherosclerotic lesions of the more proximal aorta (left side of photograph)?',
#  'Are Margin P also super-imposed on advanced atherosclerotic lesions of the more proximal aorta (left side of photograph)?',
#  'What is stained for elastic tissue?',
#  'Is a thrombosed artery stained for elastic tissue?',
#  'What is lodged in a pulmonary artery branch?',
#  'Is embolus derived from a lower-extremity deep venous thrombus lodged in a pulmonary artery branch?',
#  'Is edema lodged in a pulmonary artery branch?',
#  'What is composed of hematopoietic marrow and marrow fat cells attached to a thrombus?',
#  'What is the embolus composed of?',
#  'Is the embolus composed of hematopoietic marrow and marrow fat cells attached to a thrombus?',
#  'Is the wall of the artery composed of hematopoietic marrow and marrow fat cells attached to a thrombus?',
#  'How many small pulmonary arterioles are packed with laminated swirls of fetal squamous cells?',
#  'What are packed with laminated swirls of fetal squamous cells?',
#  'What are two small pulmonary arterioles packed with of fetal squamous cells?',
#  'Are two small pulmonary arterioles packed with laminated swirls of fetal squamous cells?',
#  'Are the photomicrographs packed with laminated swirls of fetal squamous cells?',
#  'What is edematous and congested?',
#  'Is the surrounding lung edematous and congested?',
#  'Is numerous friable mural thrombi edematous and congested?',
#  'What is replaced by a large fibrotic scar?',
#  'What is the remote kidney infarct replaced by?',
#  'How is the remote kidney infarct replaced?',
#  'Is the remote kidney infarct replaced by a large fibrotic scar?',
#  'Are the areas of white chalky deposits illustrated schematically?',
#  'What is characterized by vasodilation, congestion, and edema?',
#  'What is the immediate reaction characterized by?',
#  'Is the immediate reaction characterized by an inflammatory infiltrate rich in eosinophils,  neutrophils,  and T cells?',
#  'What is characterized by an inflammatory infiltrate rich in eosinophils,  neutrophils,  and T cells?',
#  'What is the late-phase reaction characterized by?',
#  'Is the immediate reaction characterized by an inflammatory infiltrate rich in eosinophils,  neutrophils,  and T cells?',
#  'Is typical tuberculous granuloma showing an area of central necrosis characterized by an inflammatory infiltrate rich in eosinophils,  neutrophils,  and T cells?',
#  'What reveals a predominantly perivascular cellular infiltrate that marks positively with anti-CD4 antibodies?',
#  'What does immunoperoxidase staining reveal that marks positively with anti-CD4 antibodies?',
#  'Does immunoperoxidase staining reveal a predominantly perivascular cellular infiltrate that marks positively with anti-CD4 antibodies?',
#  'Does failure to stain reveal a predominantly perivascular cellular infiltrate that marks positively with anti-CD4 antibodies?',
#  'What shows several multinucleate giant cells?',
#  'What does the granuloma in the center show?',
#  'Does the granuloma in the center show several multinucleate giant cells?',
#  'Does the left ventricular wall show several multinucleate giant cells?',
#  'What is typical of antibodies reactive with dsDNA,  nucleosomes,  and histones,  and is common in SLE?',
#  'Where is homogeneous or diffuse staining of nuclei common?',
#  'How is homogeneous or diffuse staining of nuclei?',
#  'Is homogeneous or diffuse staining of nuclei typical of antibodies reactive with dsDNA,  nucleosomes,  and histones?',
#  'Are the photomicrographs typical of antibodies reactive with dsDNA,  nucleosomes,  and histones?',
#  'Are skin stem cells typical of antibodies reactive with dsDNA,  nucleosomes,  and histones,  and common in SLE?',
#  'Are small intestine stem cells typical of antibodies reactive with dsDNA,  nucleosomes,  and histones,  and is common in SLE?',
#  'What is seen with antibodies against various nuclear antigens,  including Sm and RNPs?',
#  'What is a speckled pattern seen with?',
#  'Is a speckled pattern seen with antibodies against various nuclear antigens,  including Sm and RNPs?',
#  'Is failure to stain seen with antibodies against various nuclear antigens,  including Sm and RNPs?',
#  'Is immunoperoxidase staining seen with antibodies against various nuclear antigens,  including Sm and RNPs?',
#  'Is the wall of the artery seen with antibodies against various nuclear antigens,  including Sm and RNPs?',
#  'Is Margin P seen with antibodies against various nuclear antigens,  including Sm and RNPs?',
#  'What is seen in some cases of systemic sclerosis,  Sjogren syndrome,  and other diseases?',
#  'Is the pattern of staining of anti-centromere antibodies seen in some cases of systemic sclerosis,  Sjogren syndrome,  and other diseases?',
#  'Is the principal cellular alterations that characterize reversible cell injury and necrosis seen in some cases of systemic sclerosis,  Sjogren syndrome,  and other diseases?',
#  'Are neutrophils seen in some cases of systemic sclerosis,  Sjogren syndrome,  and other diseases?',
#  'Is the dark green polypeptides seen in some cases of systemic sclerosis,  Sjogren syndrome,  and other diseases?',
#  'Are genes that encode several proteins involved in antigen processing seen in some cases of systemic sclerosis,  Sjogren syndrome,  and other diseases?',
#  'What is typical of antibodies against nucleolar proteins?',
#  'How is a nucleolar pattern against nucleolar proteins?',
#  'Is a nucleolar pattern typical of antibodies against nucleolar proteins?',
#  'Is atrophy of the brain typical of antibodies against nucleolar proteins?',
#  'Is collagen typical of antibodies against nucleolar proteins?',
#  'Is the late-phase reaction typical of antibodies against nucleolar proteins?',
#  'Is an infarct in the brain typical of antibodies against nucleolar proteins?',
#  'What corresponds to ‘wire loops’ seen by light microscopy?',
#  'What do subendothelial dense deposits correspond to?',
#  'Do subendothelial dense deposits correspond to ‘wire loops’ seen by light microscopy?',
#  'Do thrombus in the left and right ventricular apices correspond to ‘wire loops’ seen by light microscopy?',
#  'Does methylation of particular histone residues  correspond to ‘wire loops’ seen by light microscopy?',
#  'How is extracapillary proliferation?',
#  'Is extracapillary proliferation not prominent in this case?',
#  'Is the embolus not prominent in this case?',
#  'Is atrophy of the brain not prominent in this case?',
#  'What is detected by immunofluorescence?',
#  'What is deposition of IgG antibody in a granular pattern detected by?',
#  'How is deposition of IgG antibody in a granular pattern detected?',
#  'Is deposition of IgG antibody in a granular pattern detected by immunofluorescence?',
#  'Is the immediate vascular and smooth muscle reaction to allergen detected by immunofluorescence?',
#  'What shows liquefactive degeneration of the basal layer of the epidermis and edema at the dermoepidermal junction?',
#  'What does an H&E-stained section show of the basal layer of the epidermis and edema at the dermoepidermal junction?',
#  'Does an H&E-stained section show liquefactive degeneration of the basal layer of the epidermis and edema at the dermoepidermal junction?',
#  'Does the immediate reaction show liquefactive degeneration of the basal layer of the epidermis and edema at the dermoepidermal junction?',
#  'Does the remote kidney infarct show liquefactive degeneration of the basal layer of the epidermis and edema at the dermoepidermal junction?',
#  'What reveals deposits of Ig along the dermo-epidermal junction?',
#  'What does an immunofluorescence micrograph stained for IgG reveal?',
#  'Does an immunofluorescence micrograph stained for IgG reveal deposits of Ig along the dermo-epidermal junction?',
#  'Do the relative locations,  sizes,  and distances between genes reveal deposits of Ig along the dermo-epidermal junction?',
#  'What has virtually immobilized the fingers,  creating a clawlike flexion deformity?',
#  'What does the extensive subcutaneous fibrosis create?',
#  'Does the extensive subcutaneous fibrosis create a clawlike flexion deformity?',
#  'Does the immediate reaction have virtually immobilized the fingers,  creating a clawlike flexion deformity?',
#  'What has led to cutaneous ulcerations?',
#  'What has loss of blood supply led to?',
#  'Has loss of blood supply led to cutaneous ulcerations?',
#  'Has low-power view of a cross section of a skin blister showing the epidermis led to cutaneous ulcerations?',
#  'What is manifested by inflammatory cells in the inter-stitium and between epithelial cells of the tubules tubulitis?',
#  'What is acute cellular rejection of a kidney graft manifested by in the inter-stitium and between epithelial cells of the tubules tubulitis?',
#  'How is acute cellular rejection of a kidney graft manifested?',
#  'Is acute cellular rejection of a kidney graft manifested by inflammatory cells in the inter-stitium and between epithelial cells of the tubules tubulitis?',
#  'Is periodic acid-schiff manifested by inflammatory cells in the inter-stitium and between epithelial cells of the tubules tubulitis?',
#  'What are outlined by wavy basement membranes?',
#  'What are collapsed  tubules outlined by?',
#  'Are collapsed tubules outlined by wavy basement membranes?',
#  'Are t_h17 cells in granuloma formation outlined by wavy basement membranes?',
#  'What is shown with inflammatory cells attacking and undermining the endothelium?',
#  'What is an arteriole shown with?',
#  'Is an arteriole shown with inflammatory cells attacking and undermining the endothelium arrow?',
#  'Is a section of an involved lacrimal gland shown with inflammatory cells attacking and undermining the endothelium arrow?',
#  'Does the immunoperoxidase stain show C4d deposition in peritubular capillaries and a glomerulus?',
#  'Does the acute t cell-mediated rejection stain show C4d deposition in peritubular capillaries and a glomerulus?',
#  'What stain shows C4d deposition in peritubular capillaries and a glomerulus?',
#  'What shows inflammatory cells within the capillary loops glomerulitis,  accumulation of mesangial matrix,  and duplication of the capillary basement membrane?',
#  'What does the glomerulus show within the capillary loops glomerulitis,  accumulation of mesangial matrix,  and duplication of the capillary basement membrane?',
#  'Does the glomerulus show inflammatory cells within the capillary loops glomerulitis,  accumulation of mesangial matrix,  and duplication of the capillary basement membrane?',
#  'Does the extensive subcutaneous fibrosis show inflammatory cells within the capillary loops glomerulitis,  accumulation of mesangial matrix,  and duplication of the capillary basement membrane?',
#  'What do interstitial fibrosis and tubular atrophy result from?',
#  'Do interstitial fibrosis and tubular atrophy result from arteriosclerosis of arteries and arterioles in a chronically rejecting kidney allograft?',
#  'Does a speckled pattern result from arteriosclerosis of arteries and arterioles in a chronically rejecting kidney allograft?',
#  'What shows fibrosis in this trichrome stain?',
#  'What does the blue area show in this trichrome stain,  contrasted with the normal kidney (top right)?',
#  'Does the blue area show fibrosis,  contrasted with the normal kidney right in this trichrome stain?',
#  'Does the tissue factor show fibrosis,  contrasted with the normal kidney right in this trichrome stain?',
#  'What is shown (bottom right)?',
#  'Is an artery showing prominent arteriosclerosis shown (bottom right)?',
#  'Is the embolus shown (bottom right)?',
#  'What shows apple-green birefringence under polarized light,  a diagnostic feature of amyloid?',
#  'What does Congo red staining show under polarized light,  a diagnostic feature of amyloid?',
#  'Does Congo red staining show apple-green birefringence under polarized light,  a diagnostic feature of amyloid?',
#  'Does ischemic injury showing surface blebs show apple-green birefringence under polarized light,  a diagnostic feature of amyloid?',
#  'What reveals pink-red deposits of amyloid in the walls of blood vessels and along sinusoids?',
#  'What does a section of liver stained with Congo red reveal in the walls of blood vessels and along sinusoids?',
#  'Does a section of liver stained with Congo red reveal pink-red deposits of amyloid in the walls of blood vessels and along sinusoids?',
#  'Does graft damage reveal pink-red deposits of amyloid in the walls of blood vessels and along sinusoids?',
#  'What are presented in this field?',
#  'What are small nests of epithelial cells and myxoid stroma forming?',
#  'Are small nests of epithelial cells and myxoid stroma forming cartilage and bone presented in this field?',
#  'Are cm presented in this field?',
#  'What are strikingly similar to normal squamous epithelial cells,  with intercellular bridges and nests of keratin?',
#  'How are the tumor cells?',
#  'How are the tumor cells strikingly similar to normal squamous epithelial cells?',
#  'Are the tumor cells strikingly similar to normal squamous epithelial cells,  with intercellular bridges and nests of keratin?',
#  'Are skin stem cells strikingly similar to normal squamous epithelial cells,  with intercellular bridges and nests of keratin?',
#  'What shows cellular and nuclear variation in size and shape?',
#  'Does high-power detailed view of anaplastic tumor cells show cellular and nuclear variation in size and shape?',
#  'Do the majority of tissue macrophages show cellular and nuclear variation in size and shape?',
#  'What has an abnormal tripolar spindle?',
#  'What does the prominent cell in the center field have?',
#  'Does the prominent cell in the center field have an abnormal tripolar spindle?',
#  'Does the graft damage have an abnormal tripolar spindle?',
#  'What is replaced by atypical dysplastic cells?',
#  'What is the entire thickness of the epithelium replaced by?',
#  'Is the entire thickness of the epithelium replaced by atypical dysplastic cells?',
#  'Is the transmural light area in the posterolateral left ventricle replaced by atypical dysplastic cells?',
#  'What shows that the entire thickness of the epithelium is replaced by atypical dysplastic cells?',
#  'Does the low-power view show that the entire thickness of the epithelium is replaced by atypical dysplastic cells?',
#  'Do interstitial fibrosis and tubular atrophy show that the entire thickness of the epithelium is replaced by atypical dysplastic cells?',
#  'What is orderly differentiation of squamous cells?',
#  'Is there orderly differentiation of squamous cells?',
#  'Is Margin P orderly differentiation of squamous cells?',
#  'What is there in the subepithelial stroma?',
#  'Is there no tumor in the subepithelial stroma?',
#  'Is the section of an involved lacrimal gland no tumor in the subepithelial stroma?',
#  'What is intact?',
#  'Is the basement membrane intact?',
#  'Is the prominent cell in the center field intact?',
#  'What shows failure of normal differentiation,  marked nuclear and cellular pleomorphism,  and numerous mitotic figures extending toward the surface?',
#  'What does high-power view of another region show?',
#  'Does the high-power view show failure of normal differentiation,  marked nuclear and cellular pleomorphism,  and numerous mitotic figures extending toward the surface?',
#  'Does the injurious stimulus show failure of normal differentiation,  marked nuclear and cellular pleomorphism,  and numerous mitotic figures extending toward the surface?',
#  'What is not seen in this section?',
#  'Is the intact basement membrane not seen in this section?',
#  'Is the wound around one another with regularly spaced binding of the congo red not seen in this section?',
#  'What is sharply demarcated from the whiter breast tissue?',
#  'What is the tan-colored,  encapsulated small tumor demarcated from?',
#  'Is the tan-colored,  encapsulated small tumor sharply demarcated from the whiter breast tissue?',
#  'Is the congo red staining sharply demarcated from the whiter breast tissue?',
#  'What delimits the tumor from the surrounding tissue?',
#  'What does the fibrous capsule delimit?',
#  'Does the fibrous capsule delimit the tumor from the surrounding tissue?',
#  'Does the surrounding lung delimit the tumor from the surrounding tissue?',
#  'What illustrates the invasion of breast stroma and fat by nests and cords of tumor cells?',
#  'What does microscopic view of breast carcinoma illustrate?',
#  'How does microscopic view of breast carcinoma illustrate the invasion of breast stroma and fat?',
#  'Does the microscopic view of breast carcinoma illustrate the invasion of breast stroma and fat by nests and cords of tumor cells?',
#  'Does the injurious stimulus illustrate the invasion of breast stroma and fat by nests and cords of tumor cells?',
#  'What is studded with metastatic cancer?',
#  'What is a liver studded with?',
#  'How is a liver studded?',
#  'Is a liver studded with metastatic cancer?',
#  'Is the late-phase reaction studded with metastatic cancer?',
#  'Are large,  flat cells with small nuclei typical?',
#  'Are two small pulmonary arterioles typical?',
#  'How many cells are in mitosis?',
#  'What is in mitosis?',
#  'Are numerous friable mural thrombi in mitosis?',
#  'Is nuclear pleomorphism evident?',
#  'Is atrophy of the brain evident?',
#  'Are a few interspersed neutrophils,  much smaller in size and with compact,  lobate nuclei,  seen?',
#  'What is being utilized to identify mutations that can be targeted by drugs?',
#  'What is genetic analysis of cancers being utilized to do?',
#  'Is genetic analysis of cancers being utilized to identify mutations that can be targeted by drugs?',
#  'Are the necrotic cells being utilized to identify mutations that can be targeted by drugs?',
#  'What are atrophic and replaced by fibrous tissue?',
#  'How are the parenchymal glands?',
#  'Are the parenchymal glands atrophic and replaced by fibrous tissue?',
#  'Are the necrotic cells atrophic and replaced by fibrous tissue?',
#  'What are dilated and plugged with eosinophilic mucin?',
#  'What are the ducts dilated and plugged with?',
#  'Are the ducts dilated and plugged with eosinophilic mucin?',
#  'Are iron deposits shown by a special staining process dilated and plugged with eosinophilic mucin?',
#  'What are apparent?',
#  'Are extensive mucous plugging and dilation of the tracheobronchial tree apparent?',
#  'Are low-power view of a thrombosed artery apparent?',
#  'What is the product of Pseudomonas infections?',
#  'What is the greenish discoloration?',
#  'Is the greenish discoloration the product of Pseudomonas infections?',
#  'Is collagen the product of Pseudomonas infections?',
#  'What is consolidated by a combination of both secretions and pneumonia?',
#  'What is the pulmonary parenchyma consolidated by?',
#  'Is the pulmonary parenchyma consolidated by a combination of both secretions and pneumonia?',
#  'Is numerous friable mural thrombi consolidated by a combination of both secretions and pneumonia?',
#  'What has obvious lipid vacuolation under the light microscope?',
#  'Does a large neuron have obvious lipid vacuolation under the light microscope?',
#  'Does reversibly injured myocardium have obvious lipid vacuolation under the light microscope?',
#  'What shows prominent lysosomes with whorled configurations just below part of the nucleus?',
#  'What does a portion of a neuron under the electron microscope show?',
#  'Does a portion of a neuron under the electron microscope show prominent lysosomes with whorled configurations just below part of the nucleus?',
#  'Does immunoperoxidase show prominent lysosomes with whorled configurations just below part of the nucleus?',
#  'What have a foamy,  vacuolated appearance resulting from deposition of lipids?',
#  'What do the hepatocytes and Kupffer cells have resulting from deposition of lipids?',
#  'Do the hepatocytes and Kupffer cells have a foamy,  vacuolated appearance resulting from deposition of lipids?',
#  'What are electron micrograph of Gaucher cells with?',
#  'Is electron micrograph of Gaucher cells with elongated distended lysosomes?',
#  'What are fused or ill-formed?',
#  'Are the midface structures fused or ill-formed?',
#  'What is associated with a lethal malformation,  in which the midface structures are fused or ill-formed?',
#  'What is stillbirth associated with,  in which the midface structures are fused or ill-formed?',
#  'How is stillbirth associated?',
#  'Is stillbirth associated with a lethal malformation,  in which the midface structures are fused or ill-formed?',
#  'Is the granuloma in the center associated with a lethal malformation,  in which the midface structures are fused or ill-formed?',
#  'What is associated with severe internal anomalies such as maldevelopment of the brain and cardiac defects in almost all cases?',
#  'What is this degree of external dysmorphogenesis associated with?',
#  'Is this degree of external dysmorphogenesis associated with severe internal anomalies such as maldevelopment of the brain and cardiac defects in almost all cases?',
#  'Is atrophy associated with severe internal anomalies such as maldevelopment of the brain and cardiac defects in almost all cases?',
#  'What extends from the portion of the amniotic sac to encircle the leg of the fetus?',
#  'What does the band of amnion extend from ?',
#  'Does the band of amnion extend from the portion of the amniotic sac to encircle the leg of the fetus?',
#  'Does the blue area extend from the portion of the amniotic sac to encircle the leg of the fetus?',
#  'What is at the right, in the specimen shown?',
#  'Where is the placenta, in the specimen shown?',
#  'Is the placenta at the right, in the specimen shown?',
#  'Is the cause of reversible injury at the right, in the specimen shown?',
#  'What is hematoxylin-eosin stain?',
#  'Is this hematoxylin-eosin stain?',
#  'Is this Hyaline membrane disease?',
#  'What implies impending perforation?',
#  'What does this appearance imply?',
#  'Does this appearance imply impending perforation?',
#  'Does atrophy imply impending perforation?',
#  'What corresponds to areas of hemorrhagic infarction and transmural necrosis?',
#  'What does the congested portion of the ileum correspond to?',
#  'Does the congested portion of the ileum correspond to areas of hemorrhagic infarction and transmural necrosis?',
#  'Does the b-cell antigen receptor complex correspond to areas of hemorrhagic infarction and transmural necrosis?',
#  'What has been termed cystic hygroma?',
#  'What has this condition been termed?',
#  'Is this condition cystic hygroma?',
#  'Has a nucleolar pattern been termed cystic hygroma?',
#  'What are characteristically seen with,  but not limited to,  constitutional chromosomal anomalies such as 45,  X karyotypes?',
#  'What are cystic hygromas characteristically seen with,  but not limited to?',
#  'Are cystic hygromas characteristically seen with,  but not limited to,  constitutional chromosomal anomalies such as 45,  X karyotypes?',
#  'Are the light green polypeptides characteristically seen with,  but not limited to,  constitutional chromosomal anomalies such as 45,  X karyotypes?',
#  'What is infected with parvovirus B19?',
#  'What is bone marrow from an infant infected with?',
#  'How is bone marrow from an infant infected?',
#  'Is this bone marrow from an infant infected with parvovirus B19?',
#  'Is h&e infected with parvovirus B19?',
#  'What are scattered among mature hepatocytes in this histologic preparation from an infant with nonimmune hydrops fetalis?',
#  'What are numerous islands of extramedullary hematopoiesis scattered among in this histologic preparation from an infant with nonimmune hydrops fetalis?',
#  'Are numerous islands of extramedullary hematopoiesis scattered among mature hepatocytes in this histologic preparation from an infant with nonimmune hydrops fetalis?',
#  'Are neutrophils scattered among mature hepatocytes in this histologic preparation from an infant with nonimmune hydrops fetalis?',
#  'What is less developed in the neonatal period than it is in adulthood?',
#  'Is the blood-brain barrier less developed in the neonatal period than it is in adulthood?',
#  'Are some long-lived resident tissue macrophages less developed in the neonatal period than they are in adulthood?',
#  'What occurs because the blood-brain barrier is less developed in the neonatal period than it is in adulthood?',
#  'Does this occur because the blood-brain barrier is less developed in the neonatal period than it is in adulthood?',
#  'Does the cause of reversible injury occur because the blood-brain barrier is less developed in the neonatal period than it is in adulthood?',
#  'What develop long-term neurologic sequelae?',
#  'Do infants who survive develop long-term neurologic sequelae?',
#  'Does healthy neutrophils with nuclei develop long-term neurologic sequelae?',
#  'What had undergone spontaneous regression?',
#  'Had the congenital capillary hemangioma at birth after the lesion undergone spontaneous regression?',
#  'When did the congenital capillary hemangioma after the lesion undergone spontaneous regression?',
#  'What had the congenital capillary hemangioma at 2 years of age after the lesion undergone?',
#  'Had the congenital capillary hemangioma at 2 years of age after the lesion undergone spontaneous regression?',
#  'Had thrombus in the left and right ventricular apices undergone spontaneous regression?',
#  'What is composed of small cells embedded in a finely fibrillar matrix?',
#  'What is this tumor composed of?',
#  'Is this tumor composed of small cells embedded in a finely fibrillar matrix?',
#  'Is the late-phase reaction composed of small cells embedded in a finely fibrillar matrix?',
#  'What is seen in the upper right corner?',
#  'What is a Homer-Wright pseudorosette?',
#  'Is a Homer-Wright pseudorosette seen in the upper right corner?',
#  'Is deposition of antibody on endothelium and activation of complement seen in the upper right corner?',
#  'What are characterized by clusters of large ganglion cells with vesicular nuclei and abundant eosinophilic cytoplasm arrow?',
#  'What are Ganglioneuromas characterized by?',
#  'Are Ganglioneuromas characterized by clusters of large ganglion cells with vesicular nuclei and abundant eosinophilic cytoplasm (arrow)?',
#  'Is a liver characterized by clusters of large ganglion cells with vesicular nuclei and abundant eosinophilic cytoplasm arrow?',
#  'What are presented in the background stroma?',
#  'Are spindle-shaped Schwann cells present in the background stroma?',
#  'Are infants who survive presented in the background stroma?',
#  'What is attached to the kidney?',
#  'Is FISH using a fluorescein-labeled cosmid probe for N-myc on a tissue section containing neuroblastoma attached to the kidney?',
#  'Is spindle-shaped schwann cells attached to the kidney?',
#  'What corresponds to amplified N-MYC in the form of homogeneously staining regions?',
#  'What does this correspond to in the form of homogeneously staining regions?',
#  'Does this correspond to amplified N-MYC in the form of homogeneously staining regions?',
#  'Does section of an involved lacrimal gland correspond to amplified N-MYC in the form of homogeneously staining regions?',
#  'What show no nuclear staining and background cytoplasmic staining?',
#  'What do renal tubular epithelial cells in the lower half of the photograph show ?',
#  'Do renal tubular epithelial cells in the lower half of the photograph show no nuclear staining and background cytoplasmic staining?',
#  'Do the photomicrographs show no nuclear staining and background cytoplasmic staining?',
#  'What is seen abutting the optic nerve?',
#  'What is the  poorly cohesive tumor in the retina seen abutting?',
#  'Is the poorly cohesive tumor in the retina seen abutting the optic nerve?',
#  'Is the tan-colored,  encapsulated small tumor seen abutting the optic nerve?',
#  'What is consistented with the blastemal component and interspersed primitive tubules,  representing the epithelial component?',
#  'What is the Wilms tumor with tightly packed blue cells consistent with?',
#  'Is wilms tumor with tightly packed blue cells consistented with the blastemal component and intersperse primitive tubules,  representing the epithelial component?',
#  'Does large,  flat cells with small nuclei intersperse primitive tubules,  represent the epithelial component?',
#  'What was present in other areas within this Wilms tumor,  characterized by cells with hyperchromatic,  pleomorphic nuclei,  and an abnormal mitosis (center of field)?',
#  'What was present within this Wilms tumor,  characterized by cells with hyperchromatic,  pleomorphic nuclei,  and an abnormal mitosis center of field?',
#  'Was focal anaplasia present in other areas within this Wilms tumor,  characterized by cells with hyperchromatic,  pleomorphic nuclei,  and an abnormal mitosis center of field?',
#  'Was the extensive subcutaneous fibrosis present in other areas within this Wilms tumor,  characterized by cells with hyperchromatic,  pleomorphic nuclei,  and an abnormal mitosis center of field?',
#  'What are associated with specific molecular lesions?',
#  'What are predominance of blastemal morphology and diffuse anaplasia associated with?',
#  'Are predominance of blastemal morphology and diffuse anaplasia associated with specific molecular lesions ?',
#  'Are FISH using a fluorescein-labeled cosmid probe for n-myc on a tissue section containing neuroblastoma associated with specific molecular lesions?',
#  'How many copies does the green probe hybridize to the X chromosome centromere?',
#  'How many copies does the red probe hybridize to the Y chromosome centromere?',
#  'How many copies does the aqua probe hybridize to the chromosome 18 centromere?',
#  'Does the green probe hybridize to the X chromosome centromere (one copy),  the red probe to the Y chromosome centromere (one copy),  and the aqua probe to the chromosome 18 centromere (three copies)?',
#  'Does the glomerulus hybridize to the X chromosome centromere?',
#  'How many different fluorescent probes have been used in a FISH cocktail?',
#  'What have been used in a FISH cocktail?',
#  'Have three different fluorescent probes been used in a FISH cocktail?',
#  'Have the segregation of b cells and t cells in different regions of the lymph node been used in a FISH cocktail?',
#  'How many 22q13 signals are there?',
#  'Are there two 22q13 signals?',
#  'How many chromosomes do not stain with the probe for 22q11 .2,  indicating a microdeletion in this region?',
#  'What does not stain with the probe for 22q11 .2,  indicating a microdeletion in this region?',
#  'What does one of the two chromosomes for 22q11 .2 not stain with?',
#  'Does one of the two chromosomes not stain with the probe for 22q11 .2,  indicating a microdeletion in this region?',
#  'What gives rise to the 22q11 .2 deletion syndrome (DiGeorge syndrome)?',
#  'What does this abnormality give rise to?',
#  'Does this abnormality give rise to the 22q11 .2 deletion syndrome DiGeorge syndrome?',
#  'Does sci transl give rise to the 22q11 .2 deletion syndrome DiGeorge syndrome?',
#  'What has caused a marked increase in their radiodensity,  so that they are as radiopaque as the cortical bone?',
#  'Has impaired remodeling of calcified cartilage in the epiphyses of the wrist caused a marked increase in their radiodensity,  so that they are as radiopaque as the cortical bone?',
#  'Have large,  flat cells with small nuclei caused a marked increase in their radiodensity,  so that they are as radiopaque as the cortical bone?',
#  'Impaired remodeling of calcified cartilage in the epiphyses of the wrist has caused a marked increase in whose radiodensity , so that they are as radiopaque as the cortical bone ?',
#  'Are the bridging strands of fibrous tissues evident?',
#  'Are a few interspersed neutrophils,  much smaller in size and with compact,  lobate nuclei,  evident?',
#  'What has produced extensive discoloration?',
#  'What has hemorrhage of subcutaneous vessels produced?',
#  'Has hemorrhage of subcutaneous vessels produced extensive discoloration?',
#  'Has the alveolar spaces and blood vessels produced extensive discoloration?',
#  'What is intact?',
#  'Is the skin intact?',
#  'Is the zygosity plot intact?',
#  'What is produced by radiation therapy of the neck region?',
#  'What is vascular changes and fibrosis of salivary glands produced by?',
#  'How is vascular changes and fibrosis of salivary glands produced?',
#  'Are vascular changes and fibrosis of salivary glands produced by radiation therapy of the neck region?',
#  'Are bile duct cells and canals of hering produced by radiation therapy of the neck region?',
#  'What is produced by radiation therapy of the neck region?',
#  'What is vascular changes and fibrosis of salivary glands produced by?',
#  'How is vascular changes and fibrosis of salivary glands produced?',
#  'Is vascular changes and fibrosis of salivary glands produced by radiation therapy of the neck region?',
#  'Is bile duct cells and canals of hering produced by radiation therapy of the neck region?',
#  'What is produced by radiation therapy of the neck region?',
#  'What is vascular changes and fibrosis of salivary glands produced by?',
#  'How is vascular changes and fibrosis of salivary glands produced?',
#  'Is vascular changes and fibrosis of salivary glands produced by radiation therapy of the neck region?',
#  'Is the alveolar spaces and blood vessels produced by radiation therapy of the neck region?',
#  'What appears to be too large for the emaciated body?',
#  'What does the head appear to be?',
#  'Does the head appear to be too large for the emaciated body?',
#  'Does genomic dna appear to be too large for the emaciated body?',
#  'What shows generalized edema,  seen as ascites and puffiness of the face,  hands,  and legs?',
#  'What does the infant show?',
#  'Does the infant show generalized edema,  seen as ascites and puffiness of the face,  hands,  and legs?',
#  'What is absent?',
#  'Is the palisade of cartilage absent?',
#  'What consists of uncalcified osteoid?',
#  'Do paler trabeculae consist of uncalcified osteoid?',
#  'Do interstitial fibrosis and tubular atrophy consist of uncalcified osteoid?',
#  'What are well-formed bone?',
#  'Are darker trabeculae well-formed bone?',
#  'Are the basement membrane well-formed bone?',
#  'What is bowing of legs the consequence of?',
#  'How did note bowing of legs as a consequence of the formation of poorly mineralize bone in a child?',
#  'Is bowing of legs a consequence of the formation of poorly mineralized bone in a child with rickets?',
#  'Did bile duct cells and canals of hering mineralize bone in a child with rickets?',
#  'What show distinct nuclear inclusions?',
#  'What do infected cells show?',
#  'Do infected cells show distinct nuclear inclusions?',
#  'Do energy stores show distinct nuclear inclusions?',
#  'What show diffuse granular cyto-plasm,  reflecting accumulated hepatitis B surface antigen HBsAg in chronic infections?',
#  'What do infected hepatocytes show,  reflecting accumulated hepatitis B surface antigen HBsAg in chronic infections?',
#  'Do infected hepatocytes show diffuse granular cyto-plasm,  reflecting accumulated hepatitis B surface antigen HBsAg in chronic infections?',
#  'Do those with tumors that had mycn amplification show diffuse granular cyto-plasm,  reflecting accumulated hepatitis B surface antigen HBsAg in chronic infections?',
#  'What stain preparation of sputum from a patient with pneumonia?',
#  'Is the gram stain preparation of sputum from a patient with pneumonia?',
#  'Is the polyp stain preparation of sputum from a patient with pneumonia?',
#  'What are evident?',
#  'Are  elongated cocci in pairs and short chains and a neutrophil evident?',
#  'Are impaired remodeling of calcified cartilage in the epiphyses of the wrist evident?',
#  'Does gram stain preparation of a bronchoalveolar lavage specimen show gram-negative intracellular rods typical of members of Enterobacteriaceae such as Klebsiella pneumoniae or Escherichia coli?',
#  'Does collagen stain preparation of a bronchoalveolar lavage specimen show gram-negative intracellular rods typical of members of Enterobacteriaceae such as Klebsiella pneumoniae or Escherichia coli?',
#  'Is this silver stain preparation of brain tissue from a patient with Lyme disease meningoencephalitis?',
#  'Is a homer-wright pseudorosette stain preparation of brain tissue from a patient with Lyme disease meningoencephalitis?',
#  'What takes the form of a three-dimensional sphere with the offending organism in the central area?',
#  'What does the granulomatous response take the form of ?',
#  'Does the granulomatous response take the form of a three-dimensional sphere with the offending organism in the central area?',
# ...
#  'How does non-bacterial thrombotic endocarditis manifest?',
#  'Does non-bacterial thrombotic endocarditis manifest with small - to medium-sized,  bland,  nondestructive vegetations at the line of valve closure?',
#  'Does one cusp manifest with small - to medium-sized,  bland,  nondestructive vegetations at the line of valve closure?',
#  'What heals with scarring?',
#  'Do these heal with scarring?',
#  'Do cohesive tumor in retina heal with scarring?',
#  'What is characterized by small - to medium-sized inflammatory vegetations that can be attached on either side of the valve leaflets?',
#  'Is Libman-Sacks endocarditis characterized by small - to medium-sized inflammatory vegetations that can be attached on either side of the valve leaflets?',
#  'Is homogeneous or diffuse staining of nuclei characterized by small - to medium-sized inflammatory vegetations that can be attached on either side of the valve leaflets?',
#  'What is caused by Streptococcus viridans on a previously myxomatous mitral valve?',
#  'What is subacute endocarditis caused by?',
#  'How is subacute endocarditis caused?',
#  'Is subacute endocarditis caused by streptococcus viridans on a previously myxomatous mitral valve?',
#  'Is the transmural light area in the posterolateral left ventricle caused by streptococcus viridans on a previously myxomatous mitral valve?',
#  'What is caused by staphylococcus aureus on a congenitally bicuspid aortic valve with extensive cuspal destruction and ring abscess?',
#  'What is acute endocarditis caused by?',
#  'How is acute endocarditis caused?',
#  'Is acute endocarditis caused by staphylococcus aureus on a congenitally bicuspid aortic valve with extensive cuspal destruction and ring abscess?',
#  'Is acid-fast caused by staphylococcus aureus on a congenitally bicuspid aortic valve with extensive cuspal destruction and ring abscess?',
#  'What is only loosely attached to the cusp ?',
#  'What is the thrombus  loosely attached to?',
#  'Is the thrombus only loosely attached to the cusp?',
#  'Is gram only loosely attached to the cusp?',
#  'How much dilation and hypertrophy are evident?',
#  'What is evident?',
#  'How are four-chamber dilation and hypertrophy?',
#  'Are four-chamber dilation and hypertrophy evident?',
#  'Is the pattern of staining of anti-centromere antibodies evident?',
#  'What is blue in this Masson trichrome-stained preparation?',
#  'Is collagen blue in this Masson trichrome-stained preparation?',
#  'Is Margin P blue in this Masson trichrome-stained preparation?',
#  'Does the congested portion of the ileum stain?',
#  'What is markedly dilated with focal,  almost transmural replacement of the free wall by adipose tissue and fibrosis?',
#  'What is the right ventricle markedly dilated with?',
#  'Is the right ventricle markedly dilated with focal,  almost transmural replacement of the free wall by adipose tissue and fibrosis?',
#  'What has a grossly normal appearance in this heart?',
#  'What does the left ventricle have in this heart?',
#  'Does the left ventricle have a grossly normal appearance in this heart?',
#  'Does fish use a fluorescein-labeled cosmid probe for n-myc on a tissue section containing neuroblastoma have a grossly normal appearance in this heart?',
#  'Does the injurious stimulus have a grossly normal appearance in this heart?',
#  'What is enlarged?',
#  'Is the left atrium enlarged?',
#  'Is a liver enlarged?',
#  'What bulges into the left ventricular outflow tract,  giving rise to a ‘banana-shaped’ ventricular lumen?',
#  'Does the septal muscle bulge into the left ventricular outflow tract,  giving rise to a ‘banana-shaped’ ventricular lumen?',
#  'Does acute endocarditis bulge into the left ventricular outflow tract,  giving rise to a ‘banana-shaped’ ventricular lumen?',
#  'What has been moved away from the septum to reveal a fibrous endocardial plaque?',
#  'What has the anterior mitral leaflet been moved away from?',
#  'Has the anterior mitral leaflet been moved away from the septum to reveal a fibrous endocardial plaque see text?',
#  'Has low-power view of a cross section of a skin blister showing the epidermis been moved away from the septum to reveal a fibrous endocardial plaque see text?',
#  'What is present, along with mononuclear inflammation and myofiber necrosis?',
#  'What is a myofiber distended with trypanosomes presented along with?',
#  'Is a myofiber distended with trypanosomes present,  along with mononuclear inflammation and myofiber necrosis?',
#  'Are necrotic cells present,  along with mononuclear inflammation and myofiber necrosis?',
#  'Does microscopic appearance of the thickened endocardium,  which contains smooth muscle cells and abundant acid mucopolysaccharides blue-green in this Movat stain?',
#  'Do the white circles stain?',
#  'What are also present in the red cells of this asplenic patient?',
#  'Where are howell-jolly bodies present?',
#  'Are howell-jolly bodies present in the red cells of this asplenic patient?',
#  'Are cystic hygromas present in the red cells of this asplenic patient?',
#  'What shows sickle cells,  anisocytosis,  poikilocytosis,  and target cells?',
#  'What does low magnification show?',
#  'Does low magnification show sickle cells,  anisocytosis,  poikilocytosis,  and target cells?',
#  'Does the cause of reversible injury show sickle cells,  anisocytosis,  poikilocytosis,  and target cells?',
#  'What shows an irreversibly sickled cell in the center?',
#  'What does higher magnification show in the center?',
#  'Does higher magnification show an irreversibly sickled cell in the center?',
#  'Does the surrounding lung show an irreversibly sickled cell in the center?',
#  'What plucks out these inclusions?',
#  'What do the splenic macrophages pluck out?',
#  'Do the splenic macrophages pluck out these inclusions?',
#  'Do the segregation of b cells and t cells in different regions of the lymph node pluck out these inclusions?',
#  'Are ‘bite cells’ similar to the one in this smear produced?',
#  'Are numerous islands of extramedullary hematopoiesis produced?',
#  'What contains several fragmented red cells?',
#  'What does this specimen from a patient with hemolytic uremic syndrome contain?',
#  'Does this specimen from a patient with hemolytic uremic syndrome contain several fragmented red cells?',
#  'Do those with tumors that had mycn amplification contain several fragmented red cells?',
#  'What stands out in contrast?',
#  'Does scattered,  fully hemoglobinized cells,  from a recent blood transfusion,  stand out in contrast?',
#  'Do the principal cellular alterations that characterize reversible cell injury and necrosis stand out in contrast?',
#  'What shows a hyper-segmented neutrophil with a six-lobed nucleus?',
#  'What does a peripheral blood smear show?',
#  'How does a peripheral blood smear show a hyper-segmented neutrophil?',
#  'Does a peripheral blood smear show a hyper-segmented neutrophil with a six-lobed nucleus?',
#  'Does the pattern of staining of anti-centromere antibodies show a hyper-segmented neutrophil with a six-lobed nucleus?',
#  'What results for the ALL are shown in the figure?',
#  'Does the absence of staining result for the ALL shown in the figure?',
#  'What are positive for the B cell markers CD19 and CD22?',
#  'Is CD10 a marker expressed on a subset of ALLs,  and TdT a specialized DNA polymerase that is expressed in pre-B and pre-T cells?',
#  'Are the tumor cells positive for the B cell markers CD19 and CD22 ?',
#  'Is this specimen from a patient with hemolytic uremic syndrome positive for the B cell markers CD19 and CD22 ?',
#  'Does show flow cytometry result for the ALL shown in the figure?',
#  'Does acute rheumatic mitral valvulitis result for the ALL shown in the figure?',
#  'What shows diffuse effacement of nodal architecture?',
#  'Does the low-power view show diffuse effacement of nodal architecture?',
#  'Does the vessel wall show diffuse effacement of nodal architecture?',
#  'What have the appearance of small,  round lymphocytes at high power?',
#  'What appearance do a majority of the tumor cells have?',
#  'Do a majority of the tumor cells have the appearance of small,  round lymphocytes at high power?',
#  'Do the photomicrographs have the appearance of small,  round lymphocytes at high power?',
#  'What is present in this field?',
#  'What is a prolymphocyte?',
#  'Is a ‘prolymphocyte’, a larger cell with a centrally placed nucleolus,  present in this field?',
#  'Is sci transl present in this field?',
#  'What are present throughout?',
#  'Are nodular aggregates of lymphoma cells present throughout?',
#  'Are the segregation of b cells and t cells in different regions of the lymph node present throughout?',
#  'What have large nuclei with open chromatin and prominent nucleoli?',
#  'What do the tumor cells have?',
#  'How do the tumor cells have large nuclei?',
#  'Do the tumor cells have large nuclei with open chromatin and prominent nucleoli?',
#  'Do neutrophils have large nuclei with open chromatin and prominent nucleoli?',
#  'Whose nuclei are fairly uniform,  giving a monotonous appearance?',
#  'What are fairly uniform,  giving a monotonous appearance?',
#  'How are the tumor cells and their nuclei?',
#  'Are the tumor cells and their nuclei fairly uniform,  giving a monotonous appearance?',
#  'Are the principal cellular alterations that characterize reversible cell injury and necrosis fairly uniform,  giving a monotonous appearance?',
#  'What is produced by interspersed,  lightly staining, normal microphages?',
#  'How is the ‘starry sky’ pattern produced?',
#  'Is the ‘starry sky’ pattern produced by interspersed,  lightly staining, normal microphages?',
#  'Are infective endocarditis produced by interspersed,  lightly staining, normal microphages?',
#  'What is better appreciated at a lower magnification?',
#  'How is normal macrophages?',
#  'Are normal macrophages better appreciated at a lower magnification?',
#  'Are those with tumors that had mycn amplification better appreciated at a lower magnification?',
#  'The tumor cells and whose nuclei are fairly uniform , giving a monotonous appearance ?',
#  'What are most obvious in the calvaria?',
#  'Are the sharply punched-out bone defects most obvious in the calvaria?',
#  'Are t_h2 cells most obvious in the calvaria?',
#  'What are largely replaced by plasma cells,  including atypical forms with multiple nuclei,  prominent nucleoli,  and cyto-plasmic droplets containing immunoglobulin?',
#  'What are normal marrow cells cells replaced by?',
#  'Are normal marrow cells largely replaced by plasma cells,  including atypical forms with multiple nuclei,  prominent nucleoli,  and cyto-plasmic droplets containing immunoglobulin?',
#  'Are the available anabolic circuits largely replaced by plasma cells,  including atypical forms with multiple nuclei,  prominent nucleoli,  and cyto-plasmic droplets containing immunoglobulin?',
#  'What is surrounded by lymphocytes,  macrophages,  and an eosinophil?',
#  'Is a binucleate Reed-Sternberg cell with large,  inclusion-like nucleoli and abundant cytoplasm surrounded by lymphocytes,  macrophages,  and an eosinophil?',
#  'Is the intact basement membrane surrounded by lymphocytes,  macrophages,  and an eosinophil?',
#  'What is seen lying within a clear space created by retraction of its cytoplasms?',
#  'What does the multilobed nucleus of the distinctive ‘lacunar cell’ contain?',
#  'Is a distinctive ‘lacunar cell’ with a multilobed nucleus containing many small nucleoli seen lying within a clear space created by retraction of its cytoplasms?',
#  'Is paler trabeculae seen lying within a clear space created by retraction of its cytoplasms?',
#  'A distinctive ‘lacunar cell’ with a multilobed nucleus containing many small nucleoli is seen lying within a clear space created by retraction of whose cytoplasms ?',
#  'What shows well-defined bands of pink,  acellular collagen that have subdivided the tumor cells into nodules?',
#  'Does a low-power view show well-defined bands of pink,  acellular collagen that have subdivided the tumor cells into nodules?',
#  'Does some long-lived resident tissue macrophages show well-defined bands of pink,  acellular collagen that have subdivided the tumor cells into nodules?',
#  'What is surrounded by eosinophils,  lymphocytes,  and histiocytes?',
#  'What is a diagnostic,  binucleate Reed-Sternberg cell surrounded by?',
#  'Is a diagnostic,  binucleate Reed-Sternberg cell surrounded by eosinophils,  lymphocytes,  and histiocytes?',
#  'Is the arteriolar wall surrounded by eosinophils,  lymphocytes,  and histiocytes?',
#  'What surround scattered,  large,  pale-staining lymphocytic and histiocytic variants ‘popcorn’ cells?',
#  'What do numerous mature-looking lymphocytes surround?',
#  'Do numerous mature-looking lymphocytes surround scattered,  large,  pale-staining lymphocytic and histiocytic variants (‘popcorn’ cells)?',
#  'Do small vegetations surround scattered,  large,  pale-staining lymphocytic and histiocytic variants ‘popcorn’ cells?',
#  'What results for the AML are shown in the figure?',
#  'Is the glomerulus result for the AML shown in the figure?',
#  'What are positive for the stem cell marker CD34 and the myeloid lineage specific markers CD33 and CD15 subset?',
#  'What are the tumor cells positive for?',
#  'Are the tumor cells positive for the stem cell marker CD34 and the myeloid lineage specific markers CD33 and CD15 subset?',
#  'Are genes that encode several proteins involved in antigen processing positive for the stem cell marker CD34 and the myeloid lineage specific markers CD33 and CD15 subset?',
#  'Does infective endocarditis result for the AML shown in the figure?',
#  'Are the normal areas dna content and the zygosity plot positive for the stem cell marker CD34 and the myeloid lineage specific markers CD33 and CD15 subset?',
#  'What has abnormally coarse and numerous azurophilic granules?',
#  'Do the neo-plastic promyelocytes have abnormally coarse and numerous azurophilic granules?',
#  'What include a cell in the center of the field with multiple needlelike Auer rods?',
#  'What do other characteristic findings include?',
#  'Do other characteristic findings include a cell in the center of the field with multiple needlelike Auer rods?',
#  'Do infected cells include a cell in the center of the field with multiple needlelike Auer rods?',
#  'What are present?',
#  'Are granulocytic forms at various stages of differentiation presented?',
#  'How many nucleated erythroid precursors are evident?',
#  'How are two nucleated erythroid precursors and several teardrop-shaped red cells?',
#  'Are two nucleated erythroid precursors and several teardrop-shaped red cells evident?',
#  'What were present in other fields?',
#  'Were immature myeloid cells present in other fields?',
#  'Was a myofiber distended with trypanosomes present in other fields?',
#  'What stimulates fibroblast growth and collagen deposition associated with the healing phase of injury?',
#  'Do the release of macrophage-derived fibrogenic cytokines such as transforming growth factor-beta stimulate fibroblast growth and collagen deposition associated with the healing phase of injury?',
#  'Do the dark green polypeptides stimulate fibroblast growth and collagen deposition associated with the healing phase of injury?',
#  'What are distended?',
#  'Are the principal cellular alterations that characterize reversible cell injury and necrosis distended?',
#  'What are collapsed,  while others are distended?',
#  'Are some alveoli collapsed,  while others are distended?',
#  'What are lined by bright pink hyaline membranes?',
#  'Is a ‘prolymphocyte’, a larger cell with a centrally placed nucleolus,  lined by bright pink hyaline membranes?',
#  'What is marked by resorption of hyaline membranes and thickening of alveolar septa by inflammatory cells,  fibroblasts,  and collagen?',
#  'What is the healing stage marked by?',
#  'Is the healing stage marked by resorption of hyaline membranes and thickening of alveolar septa by inflammatory cells,  fibroblasts,  and collagen?',
#  'Is the right ventricle marked by resorption of hyaline membranes and thickening of alveolar septa by inflammatory cells,  fibroblasts,  and collagen?',
#  ...]

# %%
text = cln_txt.remove_stopwords(text)
text
# Out:
# [['positively',
#   'charged',
#   'thus',
#   'allowing',
#   'compaction',
#   'negatively',
#   'charged',
#   'dna'],
#  ['histone', 'subunits', 'charged'],
#  ['histone',
#   'subunits',
#   'positively',
#   'charged',
#   'thus',
#   'allowing',
#   'compaction',
#   'negatively',
#   'charged',
#   'dna'],
#  ['liver', 'stem', 'cells', 'oval', 'cells', 'located'],
#  ['stained', 'immunohistochemical', 'stain', 'cytokeratin', '7'],
#  ['bile', 'duct', 'cells', 'canals', 'hering', 'stained', 'cytokeratin', '7'],
#  ['bile',
#   'duct',
#   'cells',
#   'canals',
#   'hering',
#   'stained',
#   'immunohistochemical',
#   'stain',
#   'cytokeratin',
#   '7'],
#  ['illustrated'],
#  ['principal',
#   'cellular',
#   'alterations',
#   'characterize',
#   'reversible',
#   'cell',
#   'injury',
#   'necrosis',
#   'illustrated'],
#  ['methylation', 'particular', 'histone', 'residues', 'illustrated'],
#  ['considered',
#   'culminate',
#   'necrosis',
#   'injurious',
#   'stimulus',
#   'removed',
#   'convention'],
#  ['reversible',
#   'injury',
#   'considered',
#   'injurious',
#   'stimulus',
#   'removed',
#   'convention'],
#  ['reversible',
#   'injury',
#   'considered',
#   'culminate',
#   'necrosis',
#   'injurious',
#   'stimulus',
#   'removed',
#   'convention'],
#  ['early',
#   'reversible',
#   'ischemic',
#   'injury',
#   'increase',
#   'eosinophilia',
#   'cytoplasm',
#   'swelling',
#   'occasional',
#   'cells'],
#  ['showing',
#   'increased',
#   'eosinophilia',
#   'cytoplasm',
#   'swelling',
#   'occasional',
#   'cells'],
#  ['ischemic', 'injury', 'show'],
#  ['early',
#   'ischemic',
#   'injury',
#   'show',
#   'surface',
#   'blebs',
#   'increase',
#   'eosinophilia',
#   'cytoplasm',
#   'swelling',
#   'occasional',
#   'cells'],
#  ['necrotic',
#   'cells',
#   'show',
#   'preserved',
#   'outlines',
#   'loss',
#   'nuclei',
#   'inflammatory',
#   'infiltrate',
#   'present',
#   'difficult',
#   'discern',
#   'magnification'],
#  ['preserved', 'outlines', 'loss', 'nuclei'],
#  ['show', 'preserved', 'outlines', 'loss', 'nuclei'],
#  ['necrotic', 'cells', 'show', 'preserved', 'outlines', 'loss', 'nuclei'],
#  ['skin', 'stem', 'cells', 'show', 'preserved', 'outlines', 'loss', 'nuclei'],
#  ['shows', 'dissolution', 'tissue'],
#  ['infarct', 'brain', 'show', 'tissue'],
#  ['infarct', 'brain', 'show', 'dissolution', 'tissue'],
#  ['preserved', 'show', 'dissolution', 'tissue'],
#  ['represent',
#   'foci',
#   'fat',
#   'necrosis',
#   'calcium',
#   'soap',
#   'formation',
#   'sites',
#   'lipid',
#   'breakdown',
#   'mesentery'],
#  ['areas',
#   'white',
#   'chalky',
#   'deposits',
#   'represent',
#   'foci',
#   'fat',
#   'necrosis',
#   'calcium',
#   'soap',
#   'formation'],
#  ['areas', 'white', 'chalky', 'deposits', 'represent'],
#  ['areas',
#   'white',
#   'chalky',
#   'deposits',
#   'represent',
#   'foci',
#   'fat',
#   'necrosis'],
#  ['areas',
#   'white',
#   'chalky',
#   'deposits',
#   'represent',
#   'foci',
#   'fat',
#   'necrosis',
#   'calcium',
#   'soap',
#   'formation',
#   'sites',
#   'lipid',
#   'breakdown',
#   'mesentery'],
#  ['histone',
#   'subunits',
#   'represent',
#   'foci',
#   'fat',
#   'necrosis',
#   'calcium',
#   'soap',
#   'formation',
#   'sites',
#   'lipid',
#   'breakdown',
#   'mesentery'],
#  ['shows',
#   'circumferential',
#   'bright',
#   'pink',
#   'area',
#   'necrosis',
#   'protein',
#   'deposition',
#   'inflammation'],
#  ['wall', 'artery', 'show', 'protein', 'deposition', 'inflammation'],
#  ['wall',
#   'artery',
#   'show',
#   'circumferential',
#   'bright',
#   'pink',
#   'area',
#   'necrosis'],
#  ['wall',
#   'artery',
#   'show',
#   'circumferential',
#   'bright',
#   'pink',
#   'area',
#   'necrosis',
#   'protein',
#   'deposition',
#   'inflammation'],
#  ['illustrated'],
#  ['cellular', 'alterations', 'apoptosis', 'illustrated'],
#  ['methylation', 'particular', 'histone', 'residues', 'illustrated'],
#  ['shown'],
#  ['apoptotic', 'cells', 'colonic', 'epithelium', 'shown'],
#  ['areas', 'white', 'chalky', 'deposits', 'shown'],
#  ['removed', 'postpartum', 'bleeding'],
#  ['gravid', 'uterus', 'removed'],
#  ['gravid', 'uterus', 'removed', 'postpartum', 'bleeding'],
#  ['injurious', 'stimulus', 'removed', 'postpartum', 'bleeding'],
#  ['ischemia'],
#  ['cause', 'reversible', 'injury'],
#  ['hypertrophy'],
#  ['cellular', 'adaptation', 'depicted', 'hypertrophy'],
#  ['infarct', 'brain', 'hypertrophy'],
#  ['ischemic', 'coagulative', 'necrosis'],
#  ['irreversible', 'injury'],
#  ['irreversible', 'injury', 'ischemic', 'coagulative', 'necrosis'],
#  ['thicker',
#   '2',
#   'cm',
#   'normal',
#   '1',
#   '1',
#   '5',
#   'cm',
#   'example',
#   'myocardial',
#   'hypertrophy',
#   'lower',
#   'left'],
#  ['many',
#   'cm',
#   'normal',
#   '1',
#   '1',
#   '5',
#   'cm',
#   'left',
#   'ventricular',
#   'wall',
#   'thicker',
#   'example',
#   'myocardial',
#   'hypertrophy',
#   'lower',
#   'left'],
#  ['left',
#   'ventricular',
#   'wall',
#   'thicker',
#   '2',
#   'cm',
#   'normal',
#   '1',
#   '1',
#   '5',
#   'cm',
#   'example',
#   'myocardial',
#   'hypertrophy',
#   'lower',
#   'left'],
#  ['reversible',
#   'injury',
#   'thicker',
#   '2',
#   'cm',
#   'normal',
#   '1',
#   '1',
#   '5',
#   'cm',
#   'example',
#   'myocardial',
#   'hypertrophy',
#   'lower',
#   'left'],
#  ['shows',
#   'functional',
#   'effects',
#   'without',
#   'gross',
#   'light',
#   'microscopic',
#   'changes',
#   'reversible',
#   'changes',
#   'cellular',
#   'swelling',
#   'fatty',
#   'change'],
#  ['reversibly',
#   'injured',
#   'myocardium',
#   'show',
#   'functional',
#   'effects',
#   'without',
#   'gross',
#   'light',
#   'microscopic',
#   'changes',
#   'reversible',
#   'changes',
#   'cellular',
#   'swelling',
#   'fatty',
#   'change'],
#  ['infarct',
#   'brain',
#   'show',
#   'functional',
#   'effects',
#   'without',
#   'gross',
#   'light',
#   'microscopic',
#   'changes',
#   'reversible',
#   'changes',
#   'cellular',
#   'swelling',
#   'fatty',
#   'change',
#   'shown'],
#  ['represents',
#   'acute',
#   'myocardial',
#   'infarction',
#   'specimen',
#   'showing',
#   'necrosis'],
#  ['transmural',
#   'light',
#   'area',
#   'posterolateral',
#   'left',
#   'ventricle',
#   'represent',
#   'specimen',
#   'showing',
#   'necrosis'],
#  ['transmural',
#   'light',
#   'area',
#   'posterolateral',
#   'left',
#   'ventricle',
#   'represent',
#   'acute',
#   'myocardial',
#   'infarction',
#   'specimen',
#   'showing',
#   'necrosis'],
#  ['reversible',
#   'injury',
#   'represent',
#   'acute',
#   'myocardial',
#   'infarction',
#   'specimen',
#   'showing',
#   'necrosis'],
#  ['many',
#   'transverse',
#   'sections',
#   'myocardium',
#   'stained',
#   'triphenyltetra',
#   'zolium',
#   'chloride',
#   'enzyme',
#   'substrate',
#   'colors',
#   'viable',
#   'myocardium',
#   'magenta'],
#  ['stained',
#   'triphenyltetra',
#   'zolium',
#   'chloride',
#   'enzyme',
#   'substrate',
#   'colors',
#   'viable',
#   'myocardium',
#   'magenta'],
#  ['three', 'transverse', 'sections', 'myocardium', 'stained'],
#  ['three',
#   'transverse',
#   'sections',
#   'myocardium',
#   'stained',
#   'triphenyltetra',
#   'zolium',
#   'chloride',
#   'enzyme',
#   'substrate',
#   'colors',
#   'viable',
#   'myocardium',
#   'magenta'],
#  ['due', 'enzyme', 'loss', 'cell', 'death'],
#  ['failure', 'stain', 'due', 'enzyme', 'loss', 'cell', 'death'],
#  ['failure', 'stain', 'due', 'enzyme', 'loss'],
#  ['atrophy', 'seen', 'brain'],
#  ['caused', 'aging', 'reduced', 'blood', 'supply'],
#  ['brain', 'caused', 'aging'],
#  ['atrophy', 'brain', 'caused', 'aging', 'reduced', 'blood', 'supply'],
#  ['reversible', 'injury', 'caused', 'aging', 'reduced', 'blood', 'supply'],
#  ['stripped', 'bottom', 'half', 'specimen', 'show', 'surface', 'brain'],
#  ['meninges', 'stripped'],
#  ['meninges',
#   'stripped',
#   'bottom',
#   'half',
#   'specimen',
#   'show',
#   'surface',
#   'brain'],
#  ['necrotic',
#   'cells',
#   'stripped',
#   'bottom',
#   'half',
#   'specimen',
#   'show',
#   'surface',
#   'brain'],
#  ['called', 'prussian', 'blue', 'reaction'],
#  ['shown',
#   'special',
#   'staining',
#   'process',
#   'called',
#   'prussian',
#   'blue',
#   'reaction'],
#  ['iron',
#   'deposits',
#   'shown',
#   'special',
#   'staining',
#   'process',
#   'call',
#   'prussian',
#   'blue',
#   'reaction'],
#  ['show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs',
#   'show',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs',
#   'show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['apoptotic',
#   'cells',
#   'colonic',
#   'epithelium',
#   'show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs', 'show', 'inflammatory', 'reaction', 'myocardium'],
#  ['show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs',
#   'show',
#   'inflammatory',
#   'reaction',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs',
#   'show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs',
#   'show',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs',
#   'show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['meninges',
#   'show',
#   'inflammatory',
#   'reaction',
#   'myocardium',
#   'ischemic',
#   'necrosis',
#   'infarction'],
#  ['photomicrographs', 'show', 'inflammatory', 'reaction', 'myocardium'],
#  ['lost', 'nuclei'],
#  ['whose', 'nuclei', 'lost'],
#  ['two', 'lost', 'whose', 'nuclei'],
#  ['two', 'lost', 'whose', 'nuclei'],
#  ['stained', 'red', 'cytoplasm', 'green'],
#  ['healthy', 'neutrophils', 'nuclei', 'stain', 'red', 'cytoplasm', 'green'],
#  ['areas',
#   'white',
#   'chalky',
#   'deposits',
#   'stain',
#   'red',
#   'cytoplasm',
#   'green'],
#  ['two', 'lost', 'whose', 'nuclei'],
#  ['separated', 'dermis', 'focal', 'collection', 'serous', 'effusion'],
#  ['low', 'power', 'view', 'cross', 'section', 'skin', 'blister', 'show'],
#  ['low',
#   'power',
#   'view',
#   'cross',
#   'section',
#   'skin',
#   'blister',
#   'show',
#   'epidermis',
#   'separated',
#   'dermis'],
#  ['low',
#   'power',
#   'view',
#   'cross',
#   'section',
#   'skin',
#   'blister',
#   'showing',
#   'epidermis',
#   'separated',
#   'dermis',
#   'focal',
#   'collection',
#   'serous',
#   'effusion'],
#  ['irreversible',
#   'injury',
#   'separated',
#   'dermis',
#   'focal',
#   'collection',
#   'serous',
#   'effusion'],
#  ['majority',
#   'tissue',
#   'macrophages',
#   'derived',
#   'hematopoietic',
#   'precursors'],
#  ['majority',
#   'tissue',
#   'macrophages',
#   'derived',
#   'hematopoietic',
#   'precursors'],
#  ['majority',
#   'tissue',
#   'macrophages',
#   'derived',
#   'hematopoietic',
#   'precursors'],
#  ['surrounded',
#   'multiple',
#   'multinucleate',
#   'giant',
#   'cells',
#   'epithelioid',
#   'cells',
#   'lymphocytes'],
#  ['typical', 'tuberculous', 'granuloma', 'show'],
#  ['area', 'central', 'necrosis', 'surrounded'],
#  ['dose',
#   'typical',
#   'tuberculous',
#   'granuloma',
#   'show',
#   'area',
#   'central',
#   'necrosis',
#   'surrounded',
#   'multiple',
#   'multinucleate',
#   'giant',
#   'cells',
#   'epithelioid',
#   'cells',
#   'lymphocytes'],
#  ['area',
#   'central',
#   'necrosis',
#   'surrounded',
#   'multiple',
#   'multinucleate',
#   'giant',
#   'cells',
#   'epithelioid',
#   'cells',
#   'lymphocytes'],
#  ['stained', 'blue', 'trichrome', 'stain'],
#  ['collagen', 'stained', 'blue', 'trichrome', 'stain'],
#  ['injurious', 'stimulus', 'stained', 'blue', 'trichrome', 'stain'],
#  ['major', 'initiator', 'coagulation'],
#  ['tissue', 'factor', 'vivo'],
#  ['tissue',
#   'factor',
#   'major',
#   'initiator',
#   'coagulation',
#   'amplified',
#   'feedback',
#   'loops',
#   'involving',
#   'thrombin',
#   'vivo'],
#  ['major',
#   'initiator',
#   'coagulation',
#   'amplified',
#   'feedback',
#   'loops',
#   'involving',
#   'thrombin'],
#  ['inactive', 'factors'],
#  ['red', 'polypeptides', 'inactive', 'factors'],
#  ['three', 'transverse', 'sections', 'myocardium', 'inactive', 'factors'],
#  ['color', 'active', 'factors'],
#  ['dark', 'green', 'polypeptides', 'active', 'factors'],
#  ['correspond', 'cofactors'],
#  ['light', 'green', 'polypeptides', 'correspond'],
#  ['light', 'green', 'polypeptides', 'correspond', 'cofactors'],
#  ['necrotic', 'cells', 'correspond', 'cofactors'],
#  ['consists',
#   'protease',
#   'substrate',
#   'reaction',
#   'accelerator',
#   'assembled',
#   'platelet',
#   'phospholipid',
#   'surface'],
#  ['initial', 'reaction', 'complex', 'consist'],
#  ['initial',
#   'reaction',
#   'complex',
#   'consist',
#   'protease',
#   'substrate',
#   'reaction',
#   'accelerator',
#   'assembled',
#   'platelet',
#   'phospholipid',
#   'surface'],
#  ['atrophy',
#   'brain',
#   'consist',
#   'protease',
#   'assembled',
#   'platelet',
#   'phospholipid',
#   'surface'],
#  ['overlies', 'white', 'fibrous', 'scar'],
#  ['thrombus', 'left', 'right', 'ventricular', 'apices', 'overlie'],
#  ['thrombus',
#   'left',
#   'right',
#   'ventricular',
#   'apices',
#   'overlie',
#   'white',
#   'fibrous',
#   'scar'],
#  ['areas',
#   'white',
#   'chalky',
#   'deposits',
#   'overlie',
#   'white',
#   'fibrous',
#   'scar'],
#  ['super',
#   'imposed',
#   'advanced',
#   'atherosclerotic',
#   'lesions',
#   'proximal',
#   'aorta',
#   'left',
#   'side',
#   'photograph'],
#  ['numerous',
#   'friable',
#   'mural',
#   'thrombi',
#   'super',
#   'imposed',
#   'advanced',
#   'atherosclerotic',
#   'lesions',
#   'proximal',
#   'aorta',
#   'left',
#   'side',
#   'photograph'],
#  ['margin',
#   'p',
#   'also',
#   'super',
#   'imposed',
#   'advanced',
#   'atherosclerotic',
#   'lesions',
#   'proximal',
#   'aorta',
#   'left',
#   'side',
#   'photograph'],
#  ['stained', 'elastic', 'tissue'],
#  ['thrombosed', 'artery', 'stained', 'elastic', 'tissue'],
#  ['lodged', 'pulmonary', 'artery', 'branch'],
#  ['embolus',
#   'derived',
#   'lower',
#   'extremity',
#   'deep',
#   'venous',
#   'thrombus',
#   'lodged',
#   'pulmonary',
#   'artery',
#   'branch'],
#  ['edema', 'lodged', 'pulmonary', 'artery', 'branch'],
#  ['composed',
#   'hematopoietic',
#   'marrow',
#   'marrow',
#   'fat',
#   'cells',
#   'attached',
#   'thrombus'],
#  ['embolus', 'composed'],
#  ['embolus',
#   'composed',
#   'hematopoietic',
#   'marrow',
#   'marrow',
#   'fat',
#   'cells',
#   'attached',
#   'thrombus'],
#  ['wall',
#   'artery',
#   'composed',
#   'hematopoietic',
#   'marrow',
#   'marrow',
#   'fat',
#   'cells',
#   'attached',
#   'thrombus'],
#  ['many',
#   'small',
#   'pulmonary',
#   'arterioles',
#   'packed',
#   'laminated',
#   'swirls',
#   'fetal',
#   'squamous',
#   'cells'],
#  ['packed', 'laminated', 'swirls', 'fetal', 'squamous', 'cells'],
#  ['two',
#   'small',
#   'pulmonary',
#   'arterioles',
#   'packed',
#   'fetal',
#   'squamous',
#   'cells'],
#  ['two',
#   'small',
#   'pulmonary',
#   'arterioles',
#   'packed',
#   'laminated',
#   'swirls',
#   'fetal',
#   'squamous',
#   'cells'],
#  ['photomicrographs',
#   'packed',
#   'laminated',
#   'swirls',
#   'fetal',
#   'squamous',
#   'cells'],
#  ['edematous', 'congested'],
#  ['surrounding', 'lung', 'edematous', 'congested'],
#  ['numerous', 'friable', 'mural', 'thrombi', 'edematous', 'congested'],
#  ['replaced', 'large', 'fibrotic', 'scar'],
#  ['remote', 'kidney', 'infarct', 'replaced'],
#  ['remote', 'kidney', 'infarct', 'replaced'],
#  ['remote', 'kidney', 'infarct', 'replaced', 'large', 'fibrotic', 'scar'],
#  ['areas', 'white', 'chalky', 'deposits', 'illustrated', 'schematically'],
#  ['characterized', 'vasodilation', 'congestion', 'edema'],
#  ['immediate', 'reaction', 'characterized'],
#  ['immediate',
#   'reaction',
#   'characterized',
#   'inflammatory',
#   'infiltrate',
#   'rich',
#   'eosinophils',
#   'neutrophils',
#   'cells'],
#  ['characterized',
#   'inflammatory',
#   'infiltrate',
#   'rich',
#   'eosinophils',
#   'neutrophils',
#   'cells'],
#  ['late', 'phase', 'reaction', 'characterized'],
#  ['immediate',
#   'reaction',
#   'characterized',
#   'inflammatory',
#   'infiltrate',
#   'rich',
#   'eosinophils',
#   'neutrophils',
#   'cells'],
#  ['typical',
#   'tuberculous',
#   'granuloma',
#   'showing',
#   'area',
#   'central',
#   'necrosis',
#   'characterized',
#   'inflammatory',
#   'infiltrate',
#   'rich',
#   'eosinophils',
#   'neutrophils',
#   'cells'],
#  ['reveals',
#   'predominantly',
#   'perivascular',
#   'cellular',
#   'infiltrate',
#   'marks',
#   'positively',
#   'anti',
#   'cd4',
#   'antibodies'],
#  ['immunoperoxidase',
#   'staining',
#   'reveal',
#   'marks',
#   'positively',
#   'anti',
#   'cd4',
#   'antibodies'],
#  ['immunoperoxidase',
#   'staining',
#   'reveal',
#   'predominantly',
#   'perivascular',
#   'cellular',
#   'infiltrate',
#   'marks',
#   'positively',
#   'anti',
#   'cd4',
#   'antibodies'],
#  ['failure',
#   'stain',
#   'reveal',
#   'predominantly',
#   'perivascular',
#   'cellular',
#   'infiltrate',
#   'marks',
#   'positively',
#   'anti',
#   'cd4',
#   'antibodies'],
#  ['shows', 'several', 'multinucleate', 'giant', 'cells'],
#  ['granuloma', 'center', 'show'],
#  ['granuloma', 'center', 'show', 'several', 'multinucleate', 'giant', 'cells'],
#  ['left',
#   'ventricular',
#   'wall',
#   'show',
#   'several',
#   'multinucleate',
#   'giant',
#   'cells'],
#  ['typical',
#   'antibodies',
#   'reactive',
#   'dsdna',
#   'nucleosomes',
#   'histones',
#   'common',
#   'sle'],
#  ['homogeneous', 'diffuse', 'staining', 'nuclei', 'common'],
#  ['homogeneous', 'diffuse', 'staining', 'nuclei'],
#  ['homogeneous',
#   'diffuse',
#   'staining',
#   'nuclei',
#   'typical',
#   'antibodies',
#   'reactive',
#   'dsdna',
#   'nucleosomes',
#   'histones'],
#  ['photomicrographs',
#   'typical',
#   'antibodies',
#   'reactive',
#   'dsdna',
#   'nucleosomes',
#   'histones'],
#  ['skin',
#   'stem',
#   'cells',
#   'typical',
#   'antibodies',
#   'reactive',
#   'dsdna',
#   'nucleosomes',
#   'histones',
#   'common',
#   'sle'],
#  ['small',
#   'intestine',
#   'stem',
#   'cells',
#   'typical',
#   'antibodies',
#   'reactive',
#   'dsdna',
#   'nucleosomes',
#   'histones',
#   'common',
#   'sle'],
#  ['seen',
#   'antibodies',
#   'various',
#   'nuclear',
#   'antigens',
#   'including',
#   'sm',
#   'rnps'],
#  ['speckled', 'pattern', 'seen'],
#  ['speckled',
#   'pattern',
#   'seen',
#   'antibodies',
#   'various',
#   'nuclear',
#   'antigens',
#   'including',
#   'sm',
#   'rnps'],
#  ['failure',
#   'stain',
#   'seen',
#   'antibodies',
#   'various',
#   'nuclear',
#   'antigens',
#   'including',
#   'sm',
#   'rnps'],
#  ['immunoperoxidase',
#   'staining',
#   'seen',
#   'antibodies',
#   'various',
#   'nuclear',
#   'antigens',
#   'including',
#   'sm',
#   'rnps'],
#  ['wall',
#   'artery',
#   'seen',
#   'antibodies',
#   'various',
#   'nuclear',
#   'antigens',
#   'including',
#   'sm',
#   'rnps'],
#  ['margin',
#   'p',
#   'seen',
#   'antibodies',
#   'various',
#   'nuclear',
#   'antigens',
#   'including',
#   'sm',
#   'rnps'],
#  ['seen', 'cases', 'systemic', 'sclerosis', 'sjogren', 'syndrome', 'diseases'],
#  ['pattern',
#   'staining',
#   'anti',
#   'centromere',
#   'antibodies',
#   'seen',
#   'cases',
#   'systemic',
#   'sclerosis',
#   'sjogren',
#   'syndrome',
#   'diseases'],
#  ['principal',
#   'cellular',
#   'alterations',
#   'characterize',
#   'reversible',
#   'cell',
#   'injury',
#   'necrosis',
#   'seen',
#   'cases',
#   'systemic',
#   'sclerosis',
#   'sjogren',
#   'syndrome',
#   'diseases'],
#  ['neutrophils',
#   'seen',
#   'cases',
#   'systemic',
#   'sclerosis',
#   'sjogren',
#   'syndrome',
#   'diseases'],
#  ['dark',
#   'green',
#   'polypeptides',
#   'seen',
#   'cases',
#   'systemic',
#   'sclerosis',
#   'sjogren',
#   'syndrome',
#   'diseases'],
#  ['genes',
#   'encode',
#   'several',
#   'proteins',
#   'involved',
#   'antigen',
#   'processing',
#   'seen',
#   'cases',
#   'systemic',
#   'sclerosis',
#   'sjogren',
#   'syndrome',
#   'diseases'],
#  ['typical', 'antibodies', 'nucleolar', 'proteins'],
#  ['nucleolar', 'pattern', 'nucleolar', 'proteins'],
#  ['nucleolar', 'pattern', 'typical', 'antibodies', 'nucleolar', 'proteins'],
#  ['atrophy', 'brain', 'typical', 'antibodies', 'nucleolar', 'proteins'],
#  ['collagen', 'typical', 'antibodies', 'nucleolar', 'proteins'],
#  ['late',
#   'phase',
#   'reaction',
#   'typical',
#   'antibodies',
#   'nucleolar',
#   'proteins'],
#  ['infarct', 'brain', 'typical', 'antibodies', 'nucleolar', 'proteins'],
#  ['corresponds', '‘wire', 'loops’', 'seen', 'light', 'microscopy'],
#  ['subendothelial', 'dense', 'deposits', 'correspond'],
#  ['subendothelial',
#   'dense',
#   'deposits',
#   'correspond',
#   '‘wire',
#   'loops’',
#   'seen',
#   'light',
#   'microscopy'],
#  ['thrombus',
#   'left',
#   'right',
#   'ventricular',
#   'apices',
#   'correspond',
#   '‘wire',
#   'loops’',
#   'seen',
#   'light',
#   'microscopy'],
#  ['methylation',
#   'particular',
#   'histone',
#   'residues',
#   'correspond',
#   '‘wire',
#   'loops’',
#   'seen',
#   'light',
#   'microscopy'],
#  ['extracapillary', 'proliferation'],
#  ['extracapillary', 'proliferation', 'prominent', 'case'],
#  ['embolus', 'prominent', 'case'],
#  ['atrophy', 'brain', 'prominent', 'case'],
#  ['detected', 'immunofluorescence'],
#  ['deposition', 'igg', 'antibody', 'granular', 'pattern', 'detected'],
#  ['deposition', 'igg', 'antibody', 'granular', 'pattern', 'detected'],
#  ['deposition',
#   'igg',
#   'antibody',
#   'granular',
#   'pattern',
#   'detected',
#   'immunofluorescence'],
#  ['immediate',
#   'vascular',
#   'smooth',
#   'muscle',
#   'reaction',
#   'allergen',
#   'detected',
#   'immunofluorescence'],
#  ['shows',
#   'liquefactive',
#   'degeneration',
#   'basal',
#   'layer',
#   'epidermis',
#   'edema',
#   'dermoepidermal',
#   'junction'],
#  ['h',
#   'e',
#   'stained',
#   'section',
#   'show',
#   'basal',
#   'layer',
#   'epidermis',
#   'edema',
#   'dermoepidermal',
#   'junction'],
#  ['h',
#   'e',
#   'stained',
#   'section',
#   'show',
#   'liquefactive',
#   'degeneration',
#   'basal',
#   'layer',
#   'epidermis',
#   'edema',
#   'dermoepidermal',
#   'junction'],
#  ['immediate',
#   'reaction',
#   'show',
#   'liquefactive',
#   'degeneration',
#   'basal',
#   'layer',
#   'epidermis',
#   'edema',
#   'dermoepidermal',
#   'junction'],
#  ['remote',
#   'kidney',
#   'infarct',
#   'show',
#   'liquefactive',
#   'degeneration',
#   'basal',
#   'layer',
#   'epidermis',
#   'edema',
#   'dermoepidermal',
#   'junction'],
#  ['reveals', 'deposits', 'ig', 'along', 'dermo', 'epidermal', 'junction'],
#  ['immunofluorescence', 'micrograph', 'stained', 'igg', 'reveal'],
#  ['immunofluorescence',
#   'micrograph',
#   'stained',
#   'igg',
#   'reveal',
#   'deposits',
#   'ig',
#   'along',
#   'dermo',
#   'epidermal',
#   'junction'],
#  ['relative',
#   'locations',
#   'sizes',
#   'distances',
#   'genes',
#   'reveal',
#   'deposits',
#   'ig',
#   'along',
#   'dermo',
#   'epidermal',
#   'junction'],
#  ['virtually',
#   'immobilized',
#   'fingers',
#   'creating',
#   'clawlike',
#   'flexion',
#   'deformity'],
#  ['extensive', 'subcutaneous', 'fibrosis', 'create'],
#  ['extensive',
#   'subcutaneous',
#   'fibrosis',
#   'create',
#   'clawlike',
#   'flexion',
#   'deformity'],
#  ['immediate',
#   'reaction',
#   'virtually',
#   'immobilized',
#   'fingers',
#   'creating',
#   'clawlike',
#   'flexion',
#   'deformity'],
#  ['led', 'cutaneous', 'ulcerations'],
#  ['loss', 'blood', 'supply', 'led'],
#  ['loss', 'blood', 'supply', 'led', 'cutaneous', 'ulcerations'],
#  ['low',
#   'power',
#   'view',
#   'cross',
#   'section',
#   'skin',
#   'blister',
#   'showing',
#   'epidermis',
#   'led',
#   'cutaneous',
#   'ulcerations'],
#  ['manifested',
#   'inflammatory',
#   'cells',
#   'inter',
#   'stitium',
#   'epithelial',
#   'cells',
#   'tubules',
#   'tubulitis'],
#  ['acute',
#   'cellular',
#   'rejection',
#   'kidney',
#   'graft',
#   'manifested',
#   'inter',
#   'stitium',
#   'epithelial',
#   'cells',
#   'tubules',
#   'tubulitis'],
#  ['acute', 'cellular', 'rejection', 'kidney', 'graft', 'manifested'],
#  ['acute',
#   'cellular',
#   'rejection',
#   'kidney',
#   'graft',
#   'manifested',
#   'inflammatory',
#   'cells',
#   'inter',
#   'stitium',
#   'epithelial',
#   'cells',
#   'tubules',
#   'tubulitis'],
#  ['periodic',
#   'acid',
#   'schiff',
#   'manifested',
#   'inflammatory',
#   'cells',
#   'inter',
#   'stitium',
#   'epithelial',
#   'cells',
#   'tubules',
#   'tubulitis'],
#  ['outlined', 'wavy', 'basement', 'membranes'],
#  ['collapsed', 'tubules', 'outlined'],
#  ['collapsed', 'tubules', 'outlined', 'wavy', 'basement', 'membranes'],
#  ['h17',
#   'cells',
#   'granuloma',
#   'formation',
#   'outlined',
#   'wavy',
#   'basement',
#   'membranes'],
#  ['shown', 'inflammatory', 'cells', 'attacking', 'undermining', 'endothelium'],
#  ['arteriole', 'shown'],
#  ['arteriole',
#   'shown',
#   'inflammatory',
#   'cells',
#   'attacking',
#   'undermining',
#   'endothelium',
#   'arrow'],
#  ['section',
#   'involved',
#   'lacrimal',
#   'gland',
#   'shown',
#   'inflammatory',
#   'cells',
#   'attacking',
#   'undermining',
#   'endothelium',
#   'arrow'],
#  ['immunoperoxidase',
#   'stain',
#   'show',
#   'c4d',
#   'deposition',
#   'peritubular',
#   'capillaries',
#   'glomerulus'],
#  ['acute',
#   'cell',
#   'mediated',
#   'rejection',
#   'stain',
#   'show',
#   'c4d',
#   'deposition',
#   'peritubular',
#   'capillaries',
#   'glomerulus'],
#  ['stain',
#   'shows',
#   'c4d',
#   'deposition',
#   'peritubular',
#   'capillaries',
#   'glomerulus'],
#  ['shows',
#   'inflammatory',
#   'cells',
#   'within',
#   'capillary',
#   'loops',
#   'glomerulitis',
#   'accumulation',
#   'mesangial',
#   'matrix',
#   'duplication',
#   'capillary',
#   'basement',
#   'membrane'],
#  ['glomerulus',
#   'show',
#   'within',
#   'capillary',
#   'loops',
#   'glomerulitis',
#   'accumulation',
#   'mesangial',
#   'matrix',
#   'duplication',
#   'capillary',
#   'basement',
#   'membrane'],
#  ['glomerulus',
#   'show',
#   'inflammatory',
#   'cells',
#   'within',
#   'capillary',
#   'loops',
#   'glomerulitis',
#   'accumulation',
#   'mesangial',
#   'matrix',
#   'duplication',
#   'capillary',
#   'basement',
#   'membrane'],
#  ['extensive',
#   'subcutaneous',
#   'fibrosis',
#   'show',
#   'inflammatory',
#   'cells',
#   'within',
#   'capillary',
#   'loops',
#   'glomerulitis',
#   'accumulation',
#   'mesangial',
#   'matrix',
#   'duplication',
#   'capillary',
#   'basement',
#   'membrane'],
#  ['interstitial', 'fibrosis', 'tubular', 'atrophy', 'result'],
#  ['interstitial',
#   'fibrosis',
#   'tubular',
#   'atrophy',
#   'result',
#   'arteriosclerosis',
#   'arteries',
#   'arterioles',
#   'chronically',
#   'rejecting',
#   'kidney',
#   'allograft'],
#  ['speckled',
#   'pattern',
#   'result',
#   'arteriosclerosis',
#   'arteries',
#   'arterioles',
#   'chronically',
#   'rejecting',
#   'kidney',
#   'allograft'],
#  ['shows', 'fibrosis', 'trichrome', 'stain'],
#  ['blue',
#   'area',
#   'show',
#   'trichrome',
#   'stain',
#   'contrasted',
#   'normal',
#   'kidney',
#   'top',
#   'right'],
#  ['blue',
#   'area',
#   'show',
#   'fibrosis',
#   'contrasted',
#   'normal',
#   'kidney',
#   'right',
#   'trichrome',
#   'stain'],
#  ['tissue',
#   'factor',
#   'show',
#   'fibrosis',
#   'contrasted',
#   'normal',
#   'kidney',
#   'right',
#   'trichrome',
#   'stain'],
#  ['shown', 'bottom', 'right'],
#  ['artery',
#   'showing',
#   'prominent',
#   'arteriosclerosis',
#   'shown',
#   'bottom',
#   'right'],
#  ['embolus', 'shown', 'bottom', 'right'],
#  ['shows',
#   'apple',
#   'green',
#   'birefringence',
#   'polarized',
#   'light',
#   'diagnostic',
#   'feature',
#   'amyloid'],
#  ['congo',
#   'red',
#   'staining',
#   'show',
#   'polarized',
#   'light',
#   'diagnostic',
#   'feature',
#   'amyloid'],
#  ['congo',
#   'red',
#   'staining',
#   'show',
#   'apple',
#   'green',
#   'birefringence',
#   'polarized',
#   'light',
#   'diagnostic',
#   'feature',
#   'amyloid'],
#  ['ischemic',
#   'injury',
#   'showing',
#   'surface',
#   'blebs',
#   'show',
#   'apple',
#   'green',
#   'birefringence',
#   'polarized',
#   'light',
#   'diagnostic',
#   'feature',
#   'amyloid'],
#  ['reveals',
#   'pink',
#   'red',
#   'deposits',
#   'amyloid',
#   'walls',
#   'blood',
#   'vessels',
#   'along',
#   'sinusoids'],
#  ['section',
#   'liver',
#   'stained',
#   'congo',
#   'red',
#   'reveal',
#   'walls',
#   'blood',
#   'vessels',
#   'along',
#   'sinusoids'],
#  ['section',
#   'liver',
#   'stained',
#   'congo',
#   'red',
#   'reveal',
#   'pink',
#   'red',
#   'deposits',
#   'amyloid',
#   'walls',
#   'blood',
#   'vessels',
#   'along',
#   'sinusoids'],
#  ['graft',
#   'damage',
#   'reveal',
#   'pink',
#   'red',
#   'deposits',
#   'amyloid',
#   'walls',
#   'blood',
#   'vessels',
#   'along',
#   'sinusoids'],
#  ['presented', 'field'],
#  ['small', 'nests', 'epithelial', 'cells', 'myxoid', 'stroma', 'forming'],
#  ['small',
#   'nests',
#   'epithelial',
#   'cells',
#   'myxoid',
#   'stroma',
#   'forming',
#   'cartilage',
#   'bone',
#   'presented',
#   'field'],
#  ['cm', 'presented', 'field'],
#  ['strikingly',
#   'similar',
#   'normal',
#   'squamous',
#   'epithelial',
#   'cells',
#   'intercellular',
#   'bridges',
#   'nests',
#   'keratin'],
#  ['tumor', 'cells'],
#  ['tumor',
#   'cells',
#   'strikingly',
#   'similar',
#   'normal',
#   'squamous',
#   'epithelial',
#   'cells'],
#  ['tumor',
#   'cells',
#   'strikingly',
#   'similar',
#   'normal',
#   'squamous',
#   'epithelial',
#   'cells',
#   'intercellular',
#   'bridges',
#   'nests',
#   'keratin'],
#  ['skin',
#   'stem',
#   'cells',
#   'strikingly',
#   'similar',
#   'normal',
#   'squamous',
#   'epithelial',
#   'cells',
#   'intercellular',
#   'bridges',
#   'nests',
#   'keratin'],
#  ['shows', 'cellular', 'nuclear', 'variation', 'size', 'shape'],
#  ['high',
#   'power',
#   'detailed',
#   'view',
#   'anaplastic',
#   'tumor',
#   'cells',
#   'show',
#   'cellular',
#   'nuclear',
#   'variation',
#   'size',
#   'shape'],
#  ['majority',
#   'tissue',
#   'macrophages',
#   'show',
#   'cellular',
#   'nuclear',
#   'variation',
#   'size',
#   'shape'],
#  ['abnormal', 'tripolar', 'spindle'],
#  ['prominent', 'cell', 'center', 'field'],
#  ['prominent', 'cell', 'center', 'field', 'abnormal', 'tripolar', 'spindle'],
#  ['graft', 'damage', 'abnormal', 'tripolar', 'spindle'],
#  ['replaced', 'atypical', 'dysplastic', 'cells'],
#  ['entire', 'thickness', 'epithelium', 'replaced'],
#  ['entire',
#   'thickness',
#   'epithelium',
#   'replaced',
#   'atypical',
#   'dysplastic',
#   'cells'],
#  ['transmural',
#   'light',
#   'area',
#   'posterolateral',
#   'left',
#   'ventricle',
#   'replaced',
#   'atypical',
#   'dysplastic',
#   'cells'],
#  ['shows',
#   'entire',
#   'thickness',
#   'epithelium',
#   'replaced',
#   'atypical',
#   'dysplastic',
#   'cells'],
#  ['low',
#   'power',
#   'view',
#   'show',
#   'entire',
#   'thickness',
#   'epithelium',
#   'replaced',
#   'atypical',
#   'dysplastic',
#   'cells'],
#  ['interstitial',
#   'fibrosis',
#   'tubular',
#   'atrophy',
#   'show',
#   'entire',
#   'thickness',
#   'epithelium',
#   'replaced',
#   'atypical',
#   'dysplastic',
#   'cells'],
#  ['orderly', 'differentiation', 'squamous', 'cells'],
#  ['orderly', 'differentiation', 'squamous', 'cells'],
#  ['margin', 'p', 'orderly', 'differentiation', 'squamous', 'cells'],
#  ['subepithelial', 'stroma'],
#  ['tumor', 'subepithelial', 'stroma'],
#  ['section',
#   'involved',
#   'lacrimal',
#   'gland',
#   'tumor',
#   'subepithelial',
#   'stroma'],
#  ['intact'],
#  ['basement', 'membrane', 'intact'],
#  ['prominent', 'cell', 'center', 'field', 'intact'],
#  ['shows',
#   'failure',
#   'normal',
#   'differentiation',
#   'marked',
#   'nuclear',
#   'cellular',
#   'pleomorphism',
#   'numerous',
#   'mitotic',
#   'figures',
#   'extending',
#   'toward',
#   'surface'],
#  ['high', 'power', 'view', 'another', 'region', 'show'],
#  ['high',
#   'power',
#   'view',
#   'show',
#   'failure',
#   'normal',
#   'differentiation',
#   'marked',
#   'nuclear',
#   'cellular',
#   'pleomorphism',
#   'numerous',
#   'mitotic',
#   'figures',
#   'extending',
#   'toward',
#   'surface'],
#  ['injurious',
#   'stimulus',
#   'show',
#   'failure',
#   'normal',
#   'differentiation',
#   'marked',
#   'nuclear',
#   'cellular',
#   'pleomorphism',
#   'numerous',
#   'mitotic',
#   'figures',
#   'extending',
#   'toward',
#   'surface'],
#  ['seen', 'section'],
#  ['intact', 'basement', 'membrane', 'seen', 'section'],
#  ['wound',
#   'around',
#   'one',
#   'another',
#   'regularly',
#   'spaced',
#   'binding',
#   'congo',
#   'red',
#   'seen',
#   'section'],
#  ['sharply', 'demarcated', 'whiter', 'breast', 'tissue'],
#  ['tan', 'colored', 'encapsulated', 'small', 'tumor', 'demarcated'],
#  ['tan',
#   'colored',
#   'encapsulated',
#   'small',
#   'tumor',
#   'sharply',
#   'demarcated',
#   'whiter',
#   'breast',
#   'tissue'],
#  ['congo',
#   'red',
#   'staining',
#   'sharply',
#   'demarcated',
#   'whiter',
#   'breast',
#   'tissue'],
#  ['delimits', 'tumor', 'surrounding', 'tissue'],
#  ['fibrous', 'capsule', 'delimit'],
#  ['fibrous', 'capsule', 'delimit', 'tumor', 'surrounding', 'tissue'],
#  ['surrounding', 'lung', 'delimit', 'tumor', 'surrounding', 'tissue'],
#  ['illustrates',
#   'invasion',
#   'breast',
#   'stroma',
#   'fat',
#   'nests',
#   'cords',
#   'tumor',
#   'cells'],
#  ['microscopic', 'view', 'breast', 'carcinoma', 'illustrate'],
#  ['microscopic',
#   'view',
#   'breast',
#   'carcinoma',
#   'illustrate',
#   'invasion',
#   'breast',
#   'stroma',
#   'fat'],
#  ['microscopic',
#   'view',
#   'breast',
#   'carcinoma',
#   'illustrate',
#   'invasion',
#   'breast',
#   'stroma',
#   'fat',
#   'nests',
#   'cords',
#   'tumor',
#   'cells'],
#  ['injurious',
#   'stimulus',
#   'illustrate',
#   'invasion',
#   'breast',
#   'stroma',
#   'fat',
#   'nests',
#   'cords',
#   'tumor',
#   'cells'],
#  ['studded', 'metastatic', 'cancer'],
#  ['liver', 'studded'],
#  ['liver', 'studded'],
#  ['liver', 'studded', 'metastatic', 'cancer'],
#  ['late', 'phase', 'reaction', 'studded', 'metastatic', 'cancer'],
#  ['large', 'flat', 'cells', 'small', 'nuclei', 'typical'],
#  ['two', 'small', 'pulmonary', 'arterioles', 'typical'],
#  ['many', 'cells', 'mitosis'],
#  ['mitosis'],
#  ['numerous', 'friable', 'mural', 'thrombi', 'mitosis'],
#  ['nuclear', 'pleomorphism', 'evident'],
#  ['atrophy', 'brain', 'evident'],
#  ['interspersed',
#   'neutrophils',
#   'much',
#   'smaller',
#   'size',
#   'compact',
#   'lobate',
#   'nuclei',
#   'seen'],
#  ['utilized', 'identify', 'mutations', 'targeted', 'drugs'],
#  ['genetic', 'analysis', 'cancers', 'utilized'],
#  ['genetic',
#   'analysis',
#   'cancers',
#   'utilized',
#   'identify',
#   'mutations',
#   'targeted',
#   'drugs'],
#  ['necrotic',
#   'cells',
#   'utilized',
#   'identify',
#   'mutations',
#   'targeted',
#   'drugs'],
#  ['atrophic', 'replaced', 'fibrous', 'tissue'],
#  ['parenchymal', 'glands'],
#  ['parenchymal', 'glands', 'atrophic', 'replaced', 'fibrous', 'tissue'],
#  ['necrotic', 'cells', 'atrophic', 'replaced', 'fibrous', 'tissue'],
#  ['dilated', 'plugged', 'eosinophilic', 'mucin'],
#  ['ducts', 'dilated', 'plugged'],
#  ['ducts', 'dilated', 'plugged', 'eosinophilic', 'mucin'],
#  ['iron',
#   'deposits',
#   'shown',
#   'special',
#   'staining',
#   'process',
#   'dilated',
#   'plugged',
#   'eosinophilic',
#   'mucin'],
#  ['apparent'],
#  ['extensive',
#   'mucous',
#   'plugging',
#   'dilation',
#   'tracheobronchial',
#   'tree',
#   'apparent'],
#  ['low', 'power', 'view', 'thrombosed', 'artery', 'apparent'],
#  ['product', 'pseudomonas', 'infections'],
#  ['greenish', 'discoloration'],
#  ['greenish', 'discoloration', 'product', 'pseudomonas', 'infections'],
#  ['collagen', 'product', 'pseudomonas', 'infections'],
#  ['consolidated', 'combination', 'secretions', 'pneumonia'],
#  ['pulmonary', 'parenchyma', 'consolidated'],
#  ['pulmonary',
#   'parenchyma',
#   'consolidated',
#   'combination',
#   'secretions',
#   'pneumonia'],
#  ['numerous',
#   'friable',
#   'mural',
#   'thrombi',
#   'consolidated',
#   'combination',
#   'secretions',
#   'pneumonia'],
#  ['obvious', 'lipid', 'vacuolation', 'light', 'microscope'],
#  ['large', 'neuron', 'obvious', 'lipid', 'vacuolation', 'light', 'microscope'],
#  ['reversibly',
#   'injured',
#   'myocardium',
#   'obvious',
#   'lipid',
#   'vacuolation',
#   'light',
#   'microscope'],
#  ['shows',
#   'prominent',
#   'lysosomes',
#   'whorled',
#   'configurations',
#   'part',
#   'nucleus'],
#  ['portion', 'neuron', 'electron', 'microscope', 'show'],
#  ['portion',
#   'neuron',
#   'electron',
#   'microscope',
#   'show',
#   'prominent',
#   'lysosomes',
#   'whorled',
#   'configurations',
#   'part',
#   'nucleus'],
#  ['immunoperoxidase',
#   'show',
#   'prominent',
#   'lysosomes',
#   'whorled',
#   'configurations',
#   'part',
#   'nucleus'],
#  ['foamy', 'vacuolated', 'appearance', 'resulting', 'deposition', 'lipids'],
#  ['hepatocytes', 'kupffer', 'cells', 'resulting', 'deposition', 'lipids'],
#  ['hepatocytes',
#   'kupffer',
#   'cells',
#   'foamy',
#   'vacuolated',
#   'appearance',
#   'resulting',
#   'deposition',
#   'lipids'],
#  ['electron', 'micrograph', 'gaucher', 'cells'],
#  ['electron',
#   'micrograph',
#   'gaucher',
#   'cells',
#   'elongated',
#   'distended',
#   'lysosomes'],
#  ['fused', 'ill', 'formed'],
#  ['midface', 'structures', 'fused', 'ill', 'formed'],
#  ['associated',
#   'lethal',
#   'malformation',
#   'midface',
#   'structures',
#   'fused',
#   'ill',
#   'formed'],
#  ['stillbirth',
#   'associated',
#   'midface',
#   'structures',
#   'fused',
#   'ill',
#   'formed'],
#  ['stillbirth', 'associated'],
#  ['stillbirth',
#   'associated',
#   'lethal',
#   'malformation',
#   'midface',
#   'structures',
#   'fused',
#   'ill',
#   'formed'],
#  ['granuloma',
#   'center',
#   'associated',
#   'lethal',
#   'malformation',
#   'midface',
#   'structures',
#   'fused',
#   'ill',
#   'formed'],
#  ['associated',
#   'severe',
#   'internal',
#   'anomalies',
#   'maldevelopment',
#   'brain',
#   'cardiac',
#   'defects',
#   'almost',
#   'cases'],
#  ['degree', 'external', 'dysmorphogenesis', 'associated'],
#  ['degree',
#   'external',
#   'dysmorphogenesis',
#   'associated',
#   'severe',
#   'internal',
#   'anomalies',
#   'maldevelopment',
#   'brain',
#   'cardiac',
#   'defects',
#   'almost',
#   'cases'],
#  ['atrophy',
#   'associated',
#   'severe',
#   'internal',
#   'anomalies',
#   'maldevelopment',
#   'brain',
#   'cardiac',
#   'defects',
#   'almost',
#   'cases'],
#  ['extends', 'portion', 'amniotic', 'sac', 'encircle', 'leg', 'fetus'],
#  ['band', 'amnion', 'extend'],
#  ['band',
#   'amnion',
#   'extend',
#   'portion',
#   'amniotic',
#   'sac',
#   'encircle',
#   'leg',
#   'fetus'],
#  ['blue',
#   'area',
#   'extend',
#   'portion',
#   'amniotic',
#   'sac',
#   'encircle',
#   'leg',
#   'fetus'],
#  ['right', 'specimen', 'shown'],
#  ['placenta', 'specimen', 'shown'],
#  ['placenta', 'right', 'specimen', 'shown'],
#  ['cause', 'reversible', 'injury', 'right', 'specimen', 'shown'],
#  ['hematoxylin', 'eosin', 'stain'],
#  ['hematoxylin', 'eosin', 'stain'],
#  ['hyaline', 'membrane', 'disease'],
#  ['implies', 'impending', 'perforation'],
#  ['appearance', 'imply'],
#  ['appearance', 'imply', 'impending', 'perforation'],
#  ['atrophy', 'imply', 'impending', 'perforation'],
#  ['corresponds',
#   'areas',
#   'hemorrhagic',
#   'infarction',
#   'transmural',
#   'necrosis'],
#  ['congested', 'portion', 'ileum', 'correspond'],
#  ['congested',
#   'portion',
#   'ileum',
#   'correspond',
#   'areas',
#   'hemorrhagic',
#   'infarction',
#   'transmural',
#   'necrosis'],
#  ['b',
#   'cell',
#   'antigen',
#   'receptor',
#   'complex',
#   'correspond',
#   'areas',
#   'hemorrhagic',
#   'infarction',
#   'transmural',
#   'necrosis'],
#  ['termed', 'cystic', 'hygroma'],
#  ['condition', 'termed'],
#  ['condition', 'cystic', 'hygroma'],
#  ['nucleolar', 'pattern', 'termed', 'cystic', 'hygroma'],
#  ['characteristically',
#   'seen',
#   'limited',
#   'constitutional',
#   'chromosomal',
#   'anomalies',
#   '45',
#   'x',
#   'karyotypes'],
#  ['cystic', 'hygromas', 'characteristically', 'seen', 'limited'],
#  ['cystic',
#   'hygromas',
#   'characteristically',
#   'seen',
#   'limited',
#   'constitutional',
#   'chromosomal',
#   'anomalies',
#   '45',
#   'x',
#   'karyotypes'],
#  ['light',
#   'green',
#   'polypeptides',
#   'characteristically',
#   'seen',
#   'limited',
#   'constitutional',
#   'chromosomal',
#   'anomalies',
#   '45',
#   'x',
#   'karyotypes'],
#  ['infected', 'parvovirus', 'b19'],
#  ['bone', 'marrow', 'infant', 'infected'],
#  ['bone', 'marrow', 'infant', 'infected'],
#  ['bone', 'marrow', 'infant', 'infected', 'parvovirus', 'b19'],
#  ['h', 'e', 'infected', 'parvovirus', 'b19'],
#  ['scattered',
#   'among',
#   'mature',
#   'hepatocytes',
#   'histologic',
#   'preparation',
#   'infant',
#   'nonimmune',
#   'hydrops',
#   'fetalis'],
#  ['numerous',
#   'islands',
#   'extramedullary',
#   'hematopoiesis',
#   'scattered',
#   'among',
#   'histologic',
#   'preparation',
#   'infant',
#   'nonimmune',
#   'hydrops',
#   'fetalis'],
#  ['numerous',
#   'islands',
#   'extramedullary',
#   'hematopoiesis',
#   'scattered',
#   'among',
#   'mature',
#   'hepatocytes',
#   'histologic',
#   'preparation',
#   'infant',
#   'nonimmune',
#   'hydrops',
#   'fetalis'],
#  ['neutrophils',
#   'scattered',
#   'among',
#   'mature',
#   'hepatocytes',
#   'histologic',
#   'preparation',
#   'infant',
#   'nonimmune',
#   'hydrops',
#   'fetalis'],
#  ['less', 'developed', 'neonatal', 'period', 'adulthood'],
#  ['blood',
#   'brain',
#   'barrier',
#   'less',
#   'developed',
#   'neonatal',
#   'period',
#   'adulthood'],
#  ['long',
#   'lived',
#   'resident',
#   'tissue',
#   'macrophages',
#   'less',
#   'developed',
#   'neonatal',
#   'period',
#   'adulthood'],
#  ['occurs',
#   'blood',
#   'brain',
#   'barrier',
#   'less',
#   'developed',
#   'neonatal',
#   'period',
#   'adulthood'],
#  ['occur',
#   'blood',
#   'brain',
#   'barrier',
#   'less',
#   'developed',
#   'neonatal',
#   'period',
#   'adulthood'],
#  ['cause',
#   'reversible',
#   'injury',
#   'occur',
#   'blood',
#   'brain',
#   'barrier',
#   'less',
#   'developed',
#   'neonatal',
#   'period',
#   'adulthood'],
#  ['develop', 'long', 'term', 'neurologic', 'sequelae'],
#  ['infants', 'survive', 'develop', 'long', 'term', 'neurologic', 'sequelae'],
#  ['healthy',
#   'neutrophils',
#   'nuclei',
#   'develop',
#   'long',
#   'term',
#   'neurologic',
#   'sequelae'],
#  ['undergone', 'spontaneous', 'regression'],
#  ['congenital',
#   'capillary',
#   'hemangioma',
#   'birth',
#   'lesion',
#   'undergone',
#   'spontaneous',
#   'regression'],
#  ['congenital',
#   'capillary',
#   'hemangioma',
#   'lesion',
#   'undergone',
#   'spontaneous',
#   'regression'],
#  ['congenital',
#   'capillary',
#   'hemangioma',
#   '2',
#   'years',
#   'age',
#   'lesion',
#   'undergone'],
#  ['congenital',
#   'capillary',
#   'hemangioma',
#   '2',
#   'years',
#   'age',
#   'lesion',
#   'undergone',
#   'spontaneous',
#   'regression'],
#  ['thrombus',
#   'left',
#   'right',
#   'ventricular',
#   'apices',
#   'undergone',
#   'spontaneous',
#   'regression'],
#  ['composed', 'small', 'cells', 'embedded', 'finely', 'fibrillar', 'matrix'],
#  ['tumor', 'composed'],
#  ['tumor',
#   'composed',
#   'small',
#   'cells',
#   'embedded',
#   'finely',
#   'fibrillar',
#   'matrix'],
#  ['late',
#   'phase',
#   'reaction',
#   'composed',
#   'small',
#   'cells',
#   'embedded',
#   'finely',
#   'fibrillar',
#   'matrix'],
#  ['seen', 'upper', 'right', 'corner'],
#  ['homer', 'wright', 'pseudorosette'],
#  ['homer', 'wright', 'pseudorosette', 'seen', 'upper', 'right', 'corner'],
#  ['deposition',
#   'antibody',
#   'endothelium',
#   'activation',
#   'complement',
#   'seen',
#   'upper',
#   'right',
#   'corner'],
#  ['characterized',
#   'clusters',
#   'large',
#   'ganglion',
#   'cells',
#   'vesicular',
#   'nuclei',
#   'abundant',
#   'eosinophilic',
#   'cytoplasm',
#   'arrow'],
#  ['ganglioneuromas', 'characterized'],
#  ['ganglioneuromas',
#   'characterized',
#   'clusters',
#   'large',
#   'ganglion',
#   'cells',
#   'vesicular',
#   'nuclei',
#   'abundant',
#   'eosinophilic',
#   'cytoplasm',
#   'arrow'],
#  ['liver',
#   'characterized',
#   'clusters',
#   'large',
#   'ganglion',
#   'cells',
#   'vesicular',
#   'nuclei',
#   'abundant',
#   'eosinophilic',
#   'cytoplasm',
#   'arrow'],
#  ['presented', 'background', 'stroma'],
#  ['spindle', 'shaped', 'schwann', 'cells', 'present', 'background', 'stroma'],
#  ['infants', 'survive', 'presented', 'background', 'stroma'],
#  ['attached', 'kidney'],
#  ['fish',
#   'using',
#   'fluorescein',
#   'labeled',
#   'cosmid',
#   'probe',
#   'n',
#   'myc',
#   'tissue',
#   'section',
#   'containing',
#   'neuroblastoma',
#   'attached',
#   'kidney'],
#  ['spindle', 'shaped', 'schwann', 'cells', 'attached', 'kidney'],
#  ['corresponds',
#   'amplified',
#   'n',
#   'myc',
#   'form',
#   'homogeneously',
#   'staining',
#   'regions'],
#  ['correspond', 'form', 'homogeneously', 'staining', 'regions'],
#  ['correspond',
#   'amplified',
#   'n',
#   'myc',
#   'form',
#   'homogeneously',
#   'staining',
#   'regions'],
#  ['section',
#   'involved',
#   'lacrimal',
#   'gland',
#   'correspond',
#   'amplified',
#   'n',
#   'myc',
#   'form',
#   'homogeneously',
#   'staining',
#   'regions'],
#  ['show', 'nuclear', 'staining', 'background', 'cytoplasmic', 'staining'],
#  ['renal',
#   'tubular',
#   'epithelial',
#   'cells',
#   'lower',
#   'half',
#   'photograph',
#   'show'],
#  ['renal',
#   'tubular',
#   'epithelial',
#   'cells',
#   'lower',
#   'half',
#   'photograph',
#   'show',
#   'nuclear',
#   'staining',
#   'background',
#   'cytoplasmic',
#   'staining'],
#  ['photomicrographs',
#   'show',
#   'nuclear',
#   'staining',
#   'background',
#   'cytoplasmic',
#   'staining'],
#  ['seen', 'abutting', 'optic', 'nerve'],
#  ['poorly', 'cohesive', 'tumor', 'retina', 'seen', 'abutting'],
#  ['poorly',
#   'cohesive',
#   'tumor',
#   'retina',
#   'seen',
#   'abutting',
#   'optic',
#   'nerve'],
#  ['tan',
#   'colored',
#   'encapsulated',
#   'small',
#   'tumor',
#   'seen',
#   'abutting',
#   'optic',
#   'nerve'],
#  ['consistented',
#   'blastemal',
#   'component',
#   'interspersed',
#   'primitive',
#   'tubules',
#   'representing',
#   'epithelial',
#   'component'],
#  ['wilms', 'tumor', 'tightly', 'packed', 'blue', 'cells', 'consistent'],
#  ['wilms',
#   'tumor',
#   'tightly',
#   'packed',
#   'blue',
#   'cells',
#   'consistented',
#   'blastemal',
#   'component',
#   'intersperse',
#   'primitive',
#   'tubules',
#   'representing',
#   'epithelial',
#   'component'],
#  ['large',
#   'flat',
#   'cells',
#   'small',
#   'nuclei',
#   'intersperse',
#   'primitive',
#   'tubules',
#   'represent',
#   'epithelial',
#   'component'],
#  ['present',
#   'areas',
#   'within',
#   'wilms',
#   'tumor',
#   'characterized',
#   'cells',
#   'hyperchromatic',
#   'pleomorphic',
#   'nuclei',
#   'abnormal',
#   'mitosis',
#   'center',
#   'field'],
#  ['present',
#   'within',
#   'wilms',
#   'tumor',
#   'characterized',
#   'cells',
#   'hyperchromatic',
#   'pleomorphic',
#   'nuclei',
#   'abnormal',
#   'mitosis',
#   'center',
#   'field'],
#  ['focal',
#   'anaplasia',
#   'present',
#   'areas',
#   'within',
#   'wilms',
#   'tumor',
#   'characterized',
#   'cells',
#   'hyperchromatic',
#   'pleomorphic',
#   'nuclei',
#   'abnormal',
#   'mitosis',
#   'center',
#   'field'],
#  ['extensive',
#   'subcutaneous',
#   'fibrosis',
#   'present',
#   'areas',
#   'within',
#   'wilms',
#   'tumor',
#   'characterized',
#   'cells',
#   'hyperchromatic',
#   'pleomorphic',
#   'nuclei',
#   'abnormal',
#   'mitosis',
#   'center',
#   'field'],
#  ['associated', 'specific', 'molecular', 'lesions'],
#  ['predominance',
#   'blastemal',
#   'morphology',
#   'diffuse',
#   'anaplasia',
#   'associated'],
#  ['predominance',
#   'blastemal',
#   'morphology',
#   'diffuse',
#   'anaplasia',
#   'associated',
#   'specific',
#   'molecular',
#   'lesions'],
#  ['fish',
#   'using',
#   'fluorescein',
#   'labeled',
#   'cosmid',
#   'probe',
#   'n',
#   'myc',
#   'tissue',
#   'section',
#   'containing',
#   'neuroblastoma',
#   'associated',
#   'specific',
#   'molecular',
#   'lesions'],
#  ['many',
#   'copies',
#   'green',
#   'probe',
#   'hybridize',
#   'x',
#   'chromosome',
#   'centromere'],
#  ['many', 'copies', 'red', 'probe', 'hybridize', 'chromosome', 'centromere'],
#  ['many',
#   'copies',
#   'aqua',
#   'probe',
#   'hybridize',
#   'chromosome',
#   '18',
#   'centromere'],
#  ['green',
#   'probe',
#   'hybridize',
#   'x',
#   'chromosome',
#   'centromere',
#   'one',
#   'copy',
#   'red',
#   'probe',
#   'chromosome',
#   'centromere',
#   'one',
#   'copy',
#   'aqua',
#   'probe',
#   'chromosome',
#   '18',
#   'centromere',
#   'three',
#   'copies'],
#  ['glomerulus', 'hybridize', 'x', 'chromosome', 'centromere'],
#  ['many', 'different', 'fluorescent', 'probes', 'used', 'fish', 'cocktail'],
#  ['used', 'fish', 'cocktail'],
#  ['three', 'different', 'fluorescent', 'probes', 'used', 'fish', 'cocktail'],
#  ['segregation',
#   'b',
#   'cells',
#   'cells',
#   'different',
#   'regions',
#   'lymph',
#   'node',
#   'used',
#   'fish',
#   'cocktail'],
#  ['many', '22q13', 'signals'],
#  ['two', '22q13', 'signals'],
#  ['many',
#   'chromosomes',
#   'stain',
#   'probe',
#   '22q11',
#   '2',
#   'indicating',
#   'microdeletion',
#   'region'],
#  ['stain', 'probe', '22q11', '2', 'indicating', 'microdeletion', 'region'],
#  ['one', 'two', 'chromosomes', '22q11', '2', 'stain'],
#  ['one',
#   'two',
#   'chromosomes',
#   'stain',
#   'probe',
#   '22q11',
#   '2',
#   'indicating',
#   'microdeletion',
#   'region'],
#  ['gives',
#   'rise',
#   '22q11',
#   '2',
#   'deletion',
#   'syndrome',
#   'digeorge',
#   'syndrome'],
#  ['abnormality', 'give', 'rise'],
#  ['abnormality',
#   'give',
#   'rise',
#   '22q11',
#   '2',
#   'deletion',
#   'syndrome',
#   'digeorge',
#   'syndrome'],
#  ['sci',
#   'transl',
#   'give',
#   'rise',
#   '22q11',
#   '2',
#   'deletion',
#   'syndrome',
#   'digeorge',
#   'syndrome'],
#  ['caused',
#   'marked',
#   'increase',
#   'radiodensity',
#   'radiopaque',
#   'cortical',
#   'bone'],
#  ['impaired',
#   'remodeling',
#   'calcified',
#   'cartilage',
#   'epiphyses',
#   'wrist',
#   'caused',
#   'marked',
#   'increase',
#   'radiodensity',
#   'radiopaque',
#   'cortical',
#   'bone'],
#  ['large',
#   'flat',
#   'cells',
#   'small',
#   'nuclei',
#   'caused',
#   'marked',
#   'increase',
#   'radiodensity',
#   'radiopaque',
#   'cortical',
#   'bone'],
#  ['impaired',
#   'remodeling',
#   'calcified',
#   'cartilage',
#   'epiphyses',
#   'wrist',
#   'caused',
#   'marked',
#   'increase',
#   'whose',
#   'radiodensity',
#   'radiopaque',
#   'cortical',
#   'bone'],
#  ['bridging', 'strands', 'fibrous', 'tissues', 'evident'],
#  ['interspersed',
#   'neutrophils',
#   'much',
#   'smaller',
#   'size',
#   'compact',
#   'lobate',
#   'nuclei',
#   'evident'],
#  ['produced', 'extensive', 'discoloration'],
#  ['hemorrhage', 'subcutaneous', 'vessels', 'produced'],
#  ['hemorrhage',
#   'subcutaneous',
#   'vessels',
#   'produced',
#   'extensive',
#   'discoloration'],
#  ['alveolar',
#   'spaces',
#   'blood',
#   'vessels',
#   'produced',
#   'extensive',
#   'discoloration'],
#  ['intact'],
#  ['skin', 'intact'],
#  ['zygosity', 'plot', 'intact'],
#  ['produced', 'radiation', 'therapy', 'neck', 'region'],
#  ['vascular', 'changes', 'fibrosis', 'salivary', 'glands', 'produced'],
#  ['vascular', 'changes', 'fibrosis', 'salivary', 'glands', 'produced'],
#  ['vascular',
#   'changes',
#   'fibrosis',
#   'salivary',
#   'glands',
#   'produced',
#   'radiation',
#   'therapy',
# ...
#   'caused',
#   'staphylococcus',
#   'aureus',
#   'congenitally',
#   'bicuspid',
#   'aortic',
#   'valve',
#   'extensive',
#   'cuspal',
#   'destruction',
#   'ring',
#   'abscess'],
#  ['loosely', 'attached', 'cusp'],
#  ['thrombus', 'loosely', 'attached'],
#  ['thrombus', 'loosely', 'attached', 'cusp'],
#  ['gram', 'loosely', 'attached', 'cusp'],
#  ['much', 'dilation', 'hypertrophy', 'evident'],
#  ['evident'],
#  ['four', 'chamber', 'dilation', 'hypertrophy'],
#  ['four', 'chamber', 'dilation', 'hypertrophy', 'evident'],
#  ['pattern', 'staining', 'anti', 'centromere', 'antibodies', 'evident'],
#  ['blue', 'masson', 'trichrome', 'stained', 'preparation'],
#  ['collagen', 'blue', 'masson', 'trichrome', 'stained', 'preparation'],
#  ['margin', 'p', 'blue', 'masson', 'trichrome', 'stained', 'preparation'],
#  ['congested', 'portion', 'ileum', 'stain'],
#  ['markedly',
#   'dilated',
#   'focal',
#   'almost',
#   'transmural',
#   'replacement',
#   'free',
#   'wall',
#   'adipose',
#   'tissue',
#   'fibrosis'],
#  ['right', 'ventricle', 'markedly', 'dilated'],
#  ['right',
#   'ventricle',
#   'markedly',
#   'dilated',
#   'focal',
#   'almost',
#   'transmural',
#   'replacement',
#   'free',
#   'wall',
#   'adipose',
#   'tissue',
#   'fibrosis'],
#  ['grossly', 'normal', 'appearance', 'heart'],
#  ['left', 'ventricle', 'heart'],
#  ['left', 'ventricle', 'grossly', 'normal', 'appearance', 'heart'],
#  ['fish',
#   'use',
#   'fluorescein',
#   'labeled',
#   'cosmid',
#   'probe',
#   'n',
#   'myc',
#   'tissue',
#   'section',
#   'containing',
#   'neuroblastoma',
#   'grossly',
#   'normal',
#   'appearance',
#   'heart'],
#  ['injurious', 'stimulus', 'grossly', 'normal', 'appearance', 'heart'],
#  ['enlarged'],
#  ['left', 'atrium', 'enlarged'],
#  ['liver', 'enlarged'],
#  ['bulges',
#   'left',
#   'ventricular',
#   'outflow',
#   'tract',
#   'giving',
#   'rise',
#   '‘banana',
#   'shaped’',
#   'ventricular',
#   'lumen'],
#  ['septal',
#   'muscle',
#   'bulge',
#   'left',
#   'ventricular',
#   'outflow',
#   'tract',
#   'giving',
#   'rise',
#   '‘banana',
#   'shaped’',
#   'ventricular',
#   'lumen'],
#  ['acute',
#   'endocarditis',
#   'bulge',
#   'left',
#   'ventricular',
#   'outflow',
#   'tract',
#   'giving',
#   'rise',
#   '‘banana',
#   'shaped’',
#   'ventricular',
#   'lumen'],
#  ['moved', 'away', 'septum', 'reveal', 'fibrous', 'endocardial', 'plaque'],
#  ['anterior', 'mitral', 'leaflet', 'moved', 'away'],
#  ['anterior',
#   'mitral',
#   'leaflet',
#   'moved',
#   'away',
#   'septum',
#   'reveal',
#   'fibrous',
#   'endocardial',
#   'plaque',
#   'see',
#   'text'],
#  ['low',
#   'power',
#   'view',
#   'cross',
#   'section',
#   'skin',
#   'blister',
#   'showing',
#   'epidermis',
#   'moved',
#   'away',
#   'septum',
#   'reveal',
#   'fibrous',
#   'endocardial',
#   'plaque',
#   'see',
#   'text'],
#  ['present', 'along', 'mononuclear', 'inflammation', 'myofiber', 'necrosis'],
#  ['myofiber', 'distended', 'trypanosomes', 'presented', 'along'],
#  ['myofiber',
#   'distended',
#   'trypanosomes',
#   'present',
#   'along',
#   'mononuclear',
#   'inflammation',
#   'myofiber',
#   'necrosis'],
#  ['necrotic',
#   'cells',
#   'present',
#   'along',
#   'mononuclear',
#   'inflammation',
#   'myofiber',
#   'necrosis'],
#  ['microscopic',
#   'appearance',
#   'thickened',
#   'endocardium',
#   'contains',
#   'smooth',
#   'muscle',
#   'cells',
#   'abundant',
#   'acid',
#   'mucopolysaccharides',
#   'blue',
#   'green',
#   'movat',
#   'stain'],
#  ['white', 'circles', 'stain'],
#  ['also', 'present', 'red', 'cells', 'asplenic', 'patient'],
#  ['howell', 'jolly', 'bodies', 'present'],
#  ['howell',
#   'jolly',
#   'bodies',
#   'present',
#   'red',
#   'cells',
#   'asplenic',
#   'patient'],
#  ['cystic', 'hygromas', 'present', 'red', 'cells', 'asplenic', 'patient'],
#  ['shows',
#   'sickle',
#   'cells',
#   'anisocytosis',
#   'poikilocytosis',
#   'target',
#   'cells'],
#  ['low', 'magnification', 'show'],
#  ['low',
#   'magnification',
#   'show',
#   'sickle',
#   'cells',
#   'anisocytosis',
#   'poikilocytosis',
#   'target',
#   'cells'],
#  ['cause',
#   'reversible',
#   'injury',
#   'show',
#   'sickle',
#   'cells',
#   'anisocytosis',
#   'poikilocytosis',
#   'target',
#   'cells'],
#  ['shows', 'irreversibly', 'sickled', 'cell', 'center'],
#  ['higher', 'magnification', 'show', 'center'],
#  ['higher',
#   'magnification',
#   'show',
#   'irreversibly',
#   'sickled',
#   'cell',
#   'center'],
#  ['surrounding', 'lung', 'show', 'irreversibly', 'sickled', 'cell', 'center'],
#  ['plucks', 'inclusions'],
#  ['splenic', 'macrophages', 'pluck'],
#  ['splenic', 'macrophages', 'pluck', 'inclusions'],
#  ['segregation',
#   'b',
#   'cells',
#   'cells',
#   'different',
#   'regions',
#   'lymph',
#   'node',
#   'pluck',
#   'inclusions'],
#  ['‘bite', 'cells’', 'similar', 'one', 'smear', 'produced'],
#  ['numerous', 'islands', 'extramedullary', 'hematopoiesis', 'produced'],
#  ['contains', 'several', 'fragmented', 'red', 'cells'],
#  ['specimen', 'patient', 'hemolytic', 'uremic', 'syndrome', 'contain'],
#  ['specimen',
#   'patient',
#   'hemolytic',
#   'uremic',
#   'syndrome',
#   'contain',
#   'several',
#   'fragmented',
#   'red',
#   'cells'],
#  ['tumors',
#   'mycn',
#   'amplification',
#   'contain',
#   'several',
#   'fragmented',
#   'red',
#   'cells'],
#  ['stands', 'contrast'],
#  ['scattered',
#   'fully',
#   'hemoglobinized',
#   'cells',
#   'recent',
#   'blood',
#   'transfusion',
#   'stand',
#   'contrast'],
#  ['principal',
#   'cellular',
#   'alterations',
#   'characterize',
#   'reversible',
#   'cell',
#   'injury',
#   'necrosis',
#   'stand',
#   'contrast'],
#  ['shows', 'hyper', 'segmented', 'neutrophil', 'six', 'lobed', 'nucleus'],
#  ['peripheral', 'blood', 'smear', 'show'],
#  ['peripheral', 'blood', 'smear', 'show', 'hyper', 'segmented', 'neutrophil'],
#  ['peripheral',
#   'blood',
#   'smear',
#   'show',
#   'hyper',
#   'segmented',
#   'neutrophil',
#   'six',
#   'lobed',
#   'nucleus'],
#  ['pattern',
#   'staining',
#   'anti',
#   'centromere',
#   'antibodies',
#   'show',
#   'hyper',
#   'segmented',
#   'neutrophil',
#   'six',
#   'lobed',
#   'nucleus'],
#  ['results', 'shown', 'figure'],
#  ['absence', 'staining', 'result', 'shown', 'figure'],
#  ['positive', 'b', 'cell', 'markers', 'cd19', 'cd22'],
#  ['cd10',
#   'marker',
#   'expressed',
#   'subset',
#   'alls',
#   'tdt',
#   'specialized',
#   'dna',
#   'polymerase',
#   'expressed',
#   'pre',
#   'b',
#   'pre',
#   'cells'],
#  ['tumor', 'cells', 'positive', 'b', 'cell', 'markers', 'cd19', 'cd22'],
#  ['specimen',
#   'patient',
#   'hemolytic',
#   'uremic',
#   'syndrome',
#   'positive',
#   'b',
#   'cell',
#   'markers',
#   'cd19',
#   'cd22'],
#  ['show', 'flow', 'cytometry', 'result', 'shown', 'figure'],
#  ['acute', 'rheumatic', 'mitral', 'valvulitis', 'result', 'shown', 'figure'],
#  ['shows', 'diffuse', 'effacement', 'nodal', 'architecture'],
#  ['low',
#   'power',
#   'view',
#   'show',
#   'diffuse',
#   'effacement',
#   'nodal',
#   'architecture'],
#  ['vessel', 'wall', 'show', 'diffuse', 'effacement', 'nodal', 'architecture'],
#  ['appearance', 'small', 'round', 'lymphocytes', 'high', 'power'],
#  ['appearance', 'majority', 'tumor', 'cells'],
#  ['majority',
#   'tumor',
#   'cells',
#   'appearance',
#   'small',
#   'round',
#   'lymphocytes',
#   'high',
#   'power'],
#  ['photomicrographs',
#   'appearance',
#   'small',
#   'round',
#   'lymphocytes',
#   'high',
#   'power'],
#  ['present', 'field'],
#  ['prolymphocyte'],
#  ['‘prolymphocyte’',
#   'larger',
#   'cell',
#   'centrally',
#   'placed',
#   'nucleolus',
#   'present',
#   'field'],
#  ['sci', 'transl', 'present', 'field'],
#  ['present', 'throughout'],
#  ['nodular', 'aggregates', 'lymphoma', 'cells', 'present', 'throughout'],
#  ['segregation',
#   'b',
#   'cells',
#   'cells',
#   'different',
#   'regions',
#   'lymph',
#   'node',
#   'present',
#   'throughout'],
#  ['large', 'nuclei', 'open', 'chromatin', 'prominent', 'nucleoli'],
#  ['tumor', 'cells'],
#  ['tumor', 'cells', 'large', 'nuclei'],
#  ['tumor',
#   'cells',
#   'large',
#   'nuclei',
#   'open',
#   'chromatin',
#   'prominent',
#   'nucleoli'],
#  ['neutrophils',
#   'large',
#   'nuclei',
#   'open',
#   'chromatin',
#   'prominent',
#   'nucleoli'],
#  ['whose',
#   'nuclei',
#   'fairly',
#   'uniform',
#   'giving',
#   'monotonous',
#   'appearance'],
#  ['fairly', 'uniform', 'giving', 'monotonous', 'appearance'],
#  ['tumor', 'cells', 'nuclei'],
#  ['tumor',
#   'cells',
#   'nuclei',
#   'fairly',
#   'uniform',
#   'giving',
#   'monotonous',
#   'appearance'],
#  ['principal',
#   'cellular',
#   'alterations',
#   'characterize',
#   'reversible',
#   'cell',
#   'injury',
#   'necrosis',
#   'fairly',
#   'uniform',
#   'giving',
#   'monotonous',
#   'appearance'],
#  ['produced', 'interspersed', 'lightly', 'staining', 'normal', 'microphages'],
#  ['‘starry', 'sky’', 'pattern', 'produced'],
#  ['‘starry',
#   'sky’',
#   'pattern',
#   'produced',
#   'interspersed',
#   'lightly',
#   'staining',
#   'normal',
#   'microphages'],
#  ['infective',
#   'endocarditis',
#   'produced',
#   'interspersed',
#   'lightly',
#   'staining',
#   'normal',
#   'microphages'],
#  ['better', 'appreciated', 'lower', 'magnification'],
#  ['normal', 'macrophages'],
#  ['normal', 'macrophages', 'better', 'appreciated', 'lower', 'magnification'],
#  ['tumors',
#   'mycn',
#   'amplification',
#   'better',
#   'appreciated',
#   'lower',
#   'magnification'],
#  ['tumor',
#   'cells',
#   'whose',
#   'nuclei',
#   'fairly',
#   'uniform',
#   'giving',
#   'monotonous',
#   'appearance'],
#  ['obvious', 'calvaria'],
#  ['sharply', 'punched', 'bone', 'defects', 'obvious', 'calvaria'],
#  ['h2', 'cells', 'obvious', 'calvaria'],
#  ['largely',
#   'replaced',
#   'plasma',
#   'cells',
#   'including',
#   'atypical',
#   'forms',
#   'multiple',
#   'nuclei',
#   'prominent',
#   'nucleoli',
#   'cyto',
#   'plasmic',
#   'droplets',
#   'containing',
#   'immunoglobulin'],
#  ['normal', 'marrow', 'cells', 'cells', 'replaced'],
#  ['normal',
#   'marrow',
#   'cells',
#   'largely',
#   'replaced',
#   'plasma',
#   'cells',
#   'including',
#   'atypical',
#   'forms',
#   'multiple',
#   'nuclei',
#   'prominent',
#   'nucleoli',
#   'cyto',
#   'plasmic',
#   'droplets',
#   'containing',
#   'immunoglobulin'],
#  ['available',
#   'anabolic',
#   'circuits',
#   'largely',
#   'replaced',
#   'plasma',
#   'cells',
#   'including',
#   'atypical',
#   'forms',
#   'multiple',
#   'nuclei',
#   'prominent',
#   'nucleoli',
#   'cyto',
#   'plasmic',
#   'droplets',
#   'containing',
#   'immunoglobulin'],
#  ['surrounded', 'lymphocytes', 'macrophages', 'eosinophil'],
#  ['binucleate',
#   'reed',
#   'sternberg',
#   'cell',
#   'large',
#   'inclusion',
#   'like',
#   'nucleoli',
#   'abundant',
#   'cytoplasm',
#   'surrounded',
#   'lymphocytes',
#   'macrophages',
#   'eosinophil'],
#  ['intact',
#   'basement',
#   'membrane',
#   'surrounded',
#   'lymphocytes',
#   'macrophages',
#   'eosinophil'],
#  ['seen',
#   'lying',
#   'within',
#   'clear',
#   'space',
#   'created',
#   'retraction',
#   'cytoplasms'],
#  ['multilobed', 'nucleus', 'distinctive', '‘lacunar', 'cell’', 'contain'],
#  ['distinctive',
#   '‘lacunar',
#   'cell’',
#   'multilobed',
#   'nucleus',
#   'containing',
#   'many',
#   'small',
#   'nucleoli',
#   'seen',
#   'lying',
#   'within',
#   'clear',
#   'space',
#   'created',
#   'retraction',
#   'cytoplasms'],
#  ['paler',
#   'trabeculae',
#   'seen',
#   'lying',
#   'within',
#   'clear',
#   'space',
#   'created',
#   'retraction',
#   'cytoplasms'],
#  ['distinctive',
#   '‘lacunar',
#   'cell’',
#   'multilobed',
#   'nucleus',
#   'containing',
#   'many',
#   'small',
#   'nucleoli',
#   'seen',
#   'lying',
#   'within',
#   'clear',
#   'space',
#   'created',
#   'retraction',
#   'whose',
#   'cytoplasms'],
#  ['shows',
#   'well',
#   'defined',
#   'bands',
#   'pink',
#   'acellular',
#   'collagen',
#   'subdivided',
#   'tumor',
#   'cells',
#   'nodules'],
#  ['low',
#   'power',
#   'view',
#   'show',
#   'well',
#   'defined',
#   'bands',
#   'pink',
#   'acellular',
#   'collagen',
#   'subdivided',
#   'tumor',
#   'cells',
#   'nodules'],
#  ['long',
#   'lived',
#   'resident',
#   'tissue',
#   'macrophages',
#   'show',
#   'well',
#   'defined',
#   'bands',
#   'pink',
#   'acellular',
#   'collagen',
#   'subdivided',
#   'tumor',
#   'cells',
#   'nodules'],
#  ['surrounded', 'eosinophils', 'lymphocytes', 'histiocytes'],
#  ['diagnostic', 'binucleate', 'reed', 'sternberg', 'cell', 'surrounded'],
#  ['diagnostic',
#   'binucleate',
#   'reed',
#   'sternberg',
#   'cell',
#   'surrounded',
#   'eosinophils',
#   'lymphocytes',
#   'histiocytes'],
#  ['arteriolar',
#   'wall',
#   'surrounded',
#   'eosinophils',
#   'lymphocytes',
#   'histiocytes'],
#  ['surround',
#   'scattered',
#   'large',
#   'pale',
#   'staining',
#   'lymphocytic',
#   'histiocytic',
#   'variants',
#   '‘popcorn’',
#   'cells'],
#  ['numerous', 'mature', 'looking', 'lymphocytes', 'surround'],
#  ['numerous',
#   'mature',
#   'looking',
#   'lymphocytes',
#   'surround',
#   'scattered',
#   'large',
#   'pale',
#   'staining',
#   'lymphocytic',
#   'histiocytic',
#   'variants',
#   '‘popcorn’',
#   'cells'],
#  ['small',
#   'vegetations',
#   'surround',
#   'scattered',
#   'large',
#   'pale',
#   'staining',
#   'lymphocytic',
#   'histiocytic',
#   'variants',
#   '‘popcorn’',
#   'cells'],
#  ['results', 'aml', 'shown', 'figure'],
#  ['glomerulus', 'result', 'aml', 'shown', 'figure'],
#  ['positive',
#   'stem',
#   'cell',
#   'marker',
#   'cd34',
#   'myeloid',
#   'lineage',
#   'specific',
#   'markers',
#   'cd33',
#   'cd15',
#   'subset'],
#  ['tumor', 'cells', 'positive'],
#  ['tumor',
#   'cells',
#   'positive',
#   'stem',
#   'cell',
#   'marker',
#   'cd34',
#   'myeloid',
#   'lineage',
#   'specific',
#   'markers',
#   'cd33',
#   'cd15',
#   'subset'],
#  ['genes',
#   'encode',
#   'several',
#   'proteins',
#   'involved',
#   'antigen',
#   'processing',
#   'positive',
#   'stem',
#   'cell',
#   'marker',
#   'cd34',
#   'myeloid',
#   'lineage',
#   'specific',
#   'markers',
#   'cd33',
#   'cd15',
#   'subset'],
#  ['infective', 'endocarditis', 'result', 'aml', 'shown', 'figure'],
#  ['normal',
#   'areas',
#   'dna',
#   'content',
#   'zygosity',
#   'plot',
#   'positive',
#   'stem',
#   'cell',
#   'marker',
#   'cd34',
#   'myeloid',
#   'lineage',
#   'specific',
#   'markers',
#   'cd33',
#   'cd15',
#   'subset'],
#  ['abnormally', 'coarse', 'numerous', 'azurophilic', 'granules'],
#  ['neo',
#   'plastic',
#   'promyelocytes',
#   'abnormally',
#   'coarse',
#   'numerous',
#   'azurophilic',
#   'granules'],
#  ['include',
#   'cell',
#   'center',
#   'field',
#   'multiple',
#   'needlelike',
#   'auer',
#   'rods'],
#  ['characteristic', 'findings', 'include'],
#  ['characteristic',
#   'findings',
#   'include',
#   'cell',
#   'center',
#   'field',
#   'multiple',
#   'needlelike',
#   'auer',
#   'rods'],
#  ['infected',
#   'cells',
#   'include',
#   'cell',
#   'center',
#   'field',
#   'multiple',
#   'needlelike',
#   'auer',
#   'rods'],
#  ['present'],
#  ['granulocytic',
#   'forms',
#   'various',
#   'stages',
#   'differentiation',
#   'presented'],
#  ['many', 'nucleated', 'erythroid', 'precursors', 'evident'],
#  ['two',
#   'nucleated',
#   'erythroid',
#   'precursors',
#   'several',
#   'teardrop',
#   'shaped',
#   'red',
#   'cells'],
#  ['two',
#   'nucleated',
#   'erythroid',
#   'precursors',
#   'several',
#   'teardrop',
#   'shaped',
#   'red',
#   'cells',
#   'evident'],
#  ['present', 'fields'],
#  ['immature', 'myeloid', 'cells', 'present', 'fields'],
#  ['myofiber', 'distended', 'trypanosomes', 'present', 'fields'],
#  ['stimulates',
#   'fibroblast',
#   'growth',
#   'collagen',
#   'deposition',
#   'associated',
#   'healing',
#   'phase',
#   'injury'],
#  ['release',
#   'macrophage',
#   'derived',
#   'fibrogenic',
#   'cytokines',
#   'transforming',
#   'growth',
#   'factor',
#   'beta',
#   'stimulate',
#   'fibroblast',
#   'growth',
#   'collagen',
#   'deposition',
#   'associated',
#   'healing',
#   'phase',
#   'injury'],
#  ['dark',
#   'green',
#   'polypeptides',
#   'stimulate',
#   'fibroblast',
#   'growth',
#   'collagen',
#   'deposition',
#   'associated',
#   'healing',
#   'phase',
#   'injury'],
#  ['distended'],
#  ['principal',
#   'cellular',
#   'alterations',
#   'characterize',
#   'reversible',
#   'cell',
#   'injury',
#   'necrosis',
#   'distended'],
#  ['collapsed', 'others', 'distended'],
#  ['alveoli', 'collapsed', 'others', 'distended'],
#  ['lined', 'bright', 'pink', 'hyaline', 'membranes'],
#  ['‘prolymphocyte’',
#   'larger',
#   'cell',
#   'centrally',
#   'placed',
#   'nucleolus',
#   'lined',
#   'bright',
#   'pink',
#   'hyaline',
#   'membranes'],
#  ['marked',
#   'resorption',
#   'hyaline',
#   'membranes',
#   'thickening',
#   'alveolar',
#   'septa',
#   'inflammatory',
#   'cells',
#   'fibroblasts',
#   'collagen'],
#  ['healing', 'stage', 'marked'],
#  ['healing',
#   'stage',
#   'marked',
#   'resorption',
#   'hyaline',
#   'membranes',
#   'thickening',
#   'alveolar',
#   'septa',
#   'inflammatory',
#   'cells',
#   'fibroblasts',
#   'collagen'],
#  ['right',
#   'ventricle',
#   'marked',
#   'resorption',
#   'hyaline',
#   'membranes',
#   'thickening',
#   'alveolar',
#   'septa',
#   'inflammatory',
#   'cells',
#   'fibroblasts',
#   'collagen'],
#  ...]

# %%
text = cln_txt.text_to_vec(text)

# %%
text[0].shape
# Out:
# (4700, 4701)

# %%
text[0][0].shape
# Out:
# (4701,)

# %%
train_set[32794]['image'].size()
# Out:
# /Users/ianleefmans/Desktop/data/train/part2/part2_images/77/3328.jpg
# torch.Size([3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(train_set[32794]['image'])) #plot indexed imaged
                                                                                         #from dataset 1716
    
                                                                                    # good test cases 841 , 1716
# Out:
# /Users/ianleefmans/Desktop/data/train/part2/part2_images/77/3328.jpg

# %%
#define custom collate function
def my_collate(batch):
    data = [item for item in batch]
    #target = [item[1] for item in batch]
    #target = torch.LongTensor(target)
    return data

# create dataloader
trainset = DataLoader(dataset=train_set,
                      batch_size=4,
                      shuffle=True)
                      #collate_fn=my_collate) # use custom collate function here
                      #pin_memory=True)

# %%
sample = iter(trainset).next() #iterate to next minibatch from dataloader
print(sample['image'][3].size()) # show size of one picture in the minibatch
# Out:
# /Users/ianleefmans/Desktop/data/train/part2/part2_images/55/2186.jpg
# /Users/ianleefmans/Desktop/data/train/part2/part2_images/56/2205.jpg
# /Users/ianleefmans/Desktop/data/train/part2/part2_images/50/2051.jpg
# /Users/ianleefmans/Desktop/data/train/part2/part2_images/62/2494.jpg
# torch.Size([3, 491, 600])

# %%
sample['image'].size()
# Out:
# torch.Size([4, 3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(sample['image'][3])) #plot image from minibatch

# %%
from pretrain_VAE import VAE

# %%
y = VAE(16).forward(sample['image'])
# Out:
# torch.Size([4, 109824])
# torch.Size([4, 2, 54912])
# torch.Size([4, 54912])

# %%
y.size(1)
# Out:
# 4

# %%
import torch.nn as nn

# %%
fc = nn.Linear(y.size(1), y.size(1)*2)
z = fc(y)

# %% [markdown]
# # Image Preprocessing Class
#
#   Class has been created. Outstanding issues:
#
#   1) Gather image size information to determine best size to conform to
#        $\textit{*this is a testing issue class does not need to be altered}$

# %% [markdown]
# #### Image expansion testing

# %%
image = Image.open('/Users/ianleefmans/Desktop/data/train/part2/part2_images/11/218.jpg') 
if image.mode != 'RGB':
    image = image.convert('RGB')
    
image.show()

# %%
preprocess = image_process((avg_height, avg_width))

# %%
# largest height: 1310
# largest width: 1544

# smallest height: 84
# smallest width: 60

avg_height = 491
avg_width = 600

image = preprocess.expand(image)
image.show()

# %%
image.getpalette
# Out:
# <bound method Image.getpalette of <PIL.Image.Image image mode=RGB size=584x491 at 0x1A292CBE10>>

# %%
transform = torchvision.transforms.ToTensor()
image = transform(image)

# %%
image2 = preprocess.uniform_size(image)

# %%
image2.size()
# Out:
# torch.Size([3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(image2))

# %% [markdown]
# #### Testing to find largest image dimensions

# %%
height = 9999999
width = 9999999
height_tot = 0
width_tot = 0
count = 0
for i in range(820):
    try:
        image = Image.open('/Users/ianleefmans/Desktop/data/train/part1/Images/Fig.'+str(i)+'.jpg')
        if image.height<height:
            height = image.height
        if image.width<width:
            width = image.width
        height_tot+= image.height
        width_tot+=image.width
        count+=1
        image.close()
    except:
        pass
    finally:
        pass
    
for i in range(886):
    try:
        image = Image.open('/Users/ianleefmans/Desktop/data/train/part1/Images/img_'+str(i)+'.jpg')
        if image.height<height:
            height = image.height
        if image.width<width:
            width = image.width
        height_tot+= image.height
        width_tot+=image.width
        count+=1
        image.close()
    except:
        pass
    finally:
        pass
    
path = '/Users/ianleefmans/Desktop/data/train'
index_dict = path_dict(path)
count_h=0
count_w=0
for i in range(3329):
    try:
        image = Image.open('/Users/ianleefmans/Desktop/data/train/part2/part2_images/'+str(index_dict[i])+ '/'+ str(i)+'.jpg')
        if image.height<height:
            height = image.height
        else:
            count_h+=1
        if image.width<width:
            width = image.width
        else:
            count_w+=1
        height_tot+= image.height
        width_tot+=image.width
        count+=1
        image.close()
    except:
        pass
    finally:
        pass
height_avg = height_tot/count
width_avg = width_tot/count

# %%
height
# Out:
# 84

# %%
width
# Out:
# 60

# %%
count_h
# Out:
# 3329

# %%
count_w
# Out:
# 3329

# %%
height_avg
# Out:
# 491.0894357743097

# %%
width_avg
# Out:
# 707.9197679071628

# %%
count
# Out:
# 4998

# %%
(708+491)/2
# Out:
# 599.5

# %%
import pandas as pd

# %%
df = pd.read_json('/Users/nylaennels/Desktop/train/part1/part1_2.json')

# %%
df.head()
# Out:
#                                 Answers Images  \
# 0                  the histone subunits  Fig.1
# 1                    positively charged  Fig.1
# 2                                   yes  Fig.1
# 3               in the canals of hering  Fig.3
# 4  bile duct cells and canals of hering  Fig.3
#
#                                            Questions
# 0  What are positively charged,  thus allowing th...
# 1              How are the histone subunits charged?
# 2  Are the histone subunits positively charged,  ...
# 3   Where are liver stem cells (oval cells) located?
# 4  What are stained here with an immunohistochemi...

# %%
len(df)
# Out:
# 32799
