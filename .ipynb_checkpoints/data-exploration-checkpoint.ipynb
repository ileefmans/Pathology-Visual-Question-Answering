# %%
import os
from PIL import Image                       # package to manipulate and import images   
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from skimage import io, transform

import torch                                # package for deeplearning
import torchvision                          # package for using images in deeplearning (computer vision)

from dataset import train_dataset

# %% [markdown]
# # Exploring the Data (Images)
# ### Convert single image to tensor and plot tensor

# %%
image = Image.open('/Users/ianleefmans/Desktop/data/train/part1/Images/Fig.1.jpg') ### image path on local device

# %%
image.getpalette # images are CMYK instead of RGB
# Out:
# <bound method Image.getpalette of <PIL.JpegImagePlugin.JpegImageFile image mode=CMYK size=335x400 at 0x1261AEC50>>

# %%
image.show() # view image

# %%
transform = torchvision.transforms.ToTensor() # create transform that changes image to tensor

# %%
image = transform(image) # transform image to tensor

# %%
image.size() # view image-tensor dimensions, there are 4 channels (CMYK) and the image is 400 pixels by 335 pixels
# Out:
# torch.Size([4, 400, 335])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='CMYK')(image))   # plot image-tensor 
                                                                    #(note the same as origional image)

# %%
image2 = Image.open('/Users/ianleefmans/Desktop/data/train/part1/Images/Fig.2.jpg')
#image2.show()
image2 = transform(image2)
image.size()
# Out:
# torch.Size([4, 790, 1020])

# %% [markdown]
# # Create Class
# ### Changing images to tensors and create dataloader
# I am beginning to create a class for importing images, converting them to tensors, and then encompassing these in a dataloader which will automatically load minibatches to be used when training our model
#
#   This should eventually be moved to a .py

# %%
# below used for testing

# %% [markdown]
# #### NEED TO FIGURE OUT PICTURE SIZES!!!!!!!

# %%
from torch.utils.data import DataLoader

images = []

#loop for first picture folder
for i in range(1,820):
    image_path = os.path.join('/Users/ianleefmans/Desktop/data/train/part1/Images', f'Fig.{i}.jpg') # image path
    image = Image.open(image_path)                                                                  # open image
    transform = torchvision.transforms.ToTensor()                                                   # transformation
    image = transform(image)                                                                        # image->tensor
    images.append(image)                                                                            # append tensor to list
    
#image_tensor = torch.stack(images)  # WANT TO CONVERT LIST TO TENSOR   # DOES NOT WORK, PICTURES DIFFERENT SIZES




#loop for second picture folder
#for i in range(13, 886):
    #image_path =
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-1ffb37e2919e> in <module>
#       9     images.append(image)                                                                            # append tensor to list
#      10
# ---> 11 image_tensor = torch.stack(images)  # WANT TO CONVERT LIST TO TENSOR   # DOES NOT WORK, PICTURES DIFFERENT SIZES
#      12
#      13
#
# RuntimeError: invalid argument 0: Sizes of tensors must match except in dimension 0. Got 400 and 84 in dimension 2 at /tmp/pip-req-build-sqyrlut3/aten/src/TH/generic/THTensor.cpp:612

# %%
train_set = train_dataset(root_dir = '/Users/ianleefmans/Desktop/data/train/part1/Images',
                         transform = torchvision.transforms.ToTensor())

# %%
def my_collate(batch):
    data = [item for item in batch]
    #target = [item[1] for item in batch]
    #target = torch.LongTensor(target)
    return data

from torch.utils.data import DataLoader
trainset = DataLoader(dataset=train_set,
                      batch_size=4,
                      shuffle=True,
                      collate_fn=my_collate) # use custom collate function here
                      #pin_memory=True)

# %%
sample = iter(trainset).next()
print(sample[1]['image'].size())
# Out:
# torch.Size([4, 312, 492])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='CMYK')(sample[2]['image']))

# %%
test_im.shape
# Out:
# (400, 335, 3)
