# %%
import os
from PIL import Image                       # package to manipulate and import images   
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import torch                                # package for deeplearning
from torch import nn
import torch.nn.functional as f
from torch.utils.data import DataLoader     # pytorch dataloader for easily loading minibatches during training
import torchvision                          # package for using images in deeplearning (computer vision)

from dataset import create_dataset, path_dict           # script for creating custom dataset

from preprocess import image_process

from nlp_preprocess import text_process

from pretrain_VAE import VAE

from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Exploring the Data (Images)
# ### Convert single image to tensor and plot tensor

# %%
image = Image.open('/Users/ianleefmans/Desktop/data/train/part2/part2_images/11/218.jpg') ### image path on local device

# %%
image.getpalette # images are CMYK instead of RGB
# Out:
# <bound method Image.getpalette of <PIL.JpegImagePlugin.JpegImageFile image mode=L size=707x594 at 0x1A4C7B3750>>

# %%
image.show() # view image

# %%
# to convert from CMYK to RGB
if image.mode != 'RGB':
    image = image.convert('RGB')
    
image.show()

# %%
transform = torchvision.transforms.ToTensor() # create transform that changes image to tensor

# %%
image = transform(image) # transform image to tensor

# %%
image.size() # view image-tensor dimensions, there are 3 channels now (RGB) and the image 
             # is 400 pixels by 335 pixels
# Out:
# torch.Size([3, 594, 707])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(image))   # plot image-tensor 
                                                                    #(note the same as origional image)

# %% [markdown]
# # Dataset Class
# ### Changing images to tensors and create dataloader
# Class has been created. Here are the outstanding issues:
#
#   1) add option for varying image size (probably not neccessary)
#   2) need to add captions if they can be accessed

# %% [markdown]
# #### Below is used for testing:

# %%
annotation_path = '/Users/ianleefmans/Desktop/data/train/part1/part1_2.json'
path = '/Users/ianleefmans/Desktop/data/train'
index_dict = path_dict(path, 3329, 78)


annotation = pd.read_json(annotation_path)

# %%
cleanques = text_process(annotation.Questions)
ques = torch.tensor(cleanques.text_preprocess()[0])
#ques = torch.tensor(ques[0])

# %%
annotation.shape
# Out:
# (32799, 3)

# %%
ques.size()
# Out:
# torch.Size([32799, 3785])

# %%
#CREATE TRAIN DATASET CLASS

# Define arguments for train_dataset class
annotation_path = '/Users/ianleefmans/Desktop/data/train/part1/part1_2.json'
path = '/Users/ianleefmans/Desktop/data/train'
index_dict = path_dict(path, 3329, 78)


annotation = pd.read_json(annotation_path)

cleanques = text_process(annotation.Questions)
ques = cleanques.text_preprocess()
ques = torch.tensor(ques[0])

cleanans = text_process(annotation.Answers)
ans = cleanans.text_preprocess()
ans = torch.tensor(ans[0])

#create trainset
train_set = create_dataset(annotation_path, ques, ans, index_dict, img_dir = path,  
                          transform = torchvision.transforms.ToTensor())

# %%
train_set[32763][0].size()
# Out:
# torch.Size([3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(train_set[32590][0])) #plot indexed imaged
                                                                                         #from dataset 1716
    
                                                                                    # good test cases 841 , 1716

# %%
#define custom collate function

#def my_collate1(batch):
    #data = [item for item in batch]
    #target = [item[1] for item in batch]
    #target = torch.LongTensor(target)
    #return data

    

# create dataloader
train_loader = DataLoader(dataset=train_set,
                      batch_size=4,
                      num_workers=4,
                      shuffle=False)
                      #collate_fn=my_collate) # use custom collate function here
                      #pin_memory=True)

# %%
sample = iter(train_loader).next() #iterate to next minibatch from dataloader
print(sample[0][0].size()) # show size of one picture in the minibatch
# Out:
# torch.Size([3, 491, 600])

# %%
sample[0].size()
# Out:
# torch.Size([4, 3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(sample[0][3])) #plot image from minibatch

# %%
#### validation dataloader

# %%
annotation_path = '/Users/ianleefmans/Desktop/data/val/part3.json'
path = '/Users/ianleefmans/Desktop/data/val'
index_dict = path_dict(path,2424,25, training=False)


annotation = pd.read_json(annotation_path)

cleanques = text_process(annotation.Questions)
ques = cleanques.text_preprocess()
ques = torch.tensor(ques[0])

cleanans = text_process(annotation.Answers)
ans = cleanans.text_preprocess()
ans = torch.tensor(ans[0])

#create trainset
val_set = create_dataset(annotation_path, ques, ans, index_dict, img_dir = path, 
                          transform = torchvision.transforms.ToTensor(), training=False)

# %%
#def my_collate(batch):
    #data = [item for item in batch]
    #target = [item[1] for item in batch]
    #target = torch.LongTensor(target)
    #return data

# create dataloader
val_loader = DataLoader(dataset=val_set,
                      batch_size=4,
                      shuffle=True)
                      #collate_fn=my_collate) # use custom collate function here
                      #pin_memory=True)

# %%
sample = iter(val_loader).next() #iterate to next minibatch from dataloader
print(sample[0][3].size()) # show size of one picture in the minibatch
# Out:
# torch.Size([3, 491, 600])

# %%
sample[0].size()
# Out:
# torch.Size([4, 3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(sample[0][3])) #plot image from minibatch

# %% [markdown]
# # Pretrain Class
# ### Variational Autoencoder to train weights of CNN portion of the model
# Class has been created. Here are some outstanding issues:
#
#   1) need to add comments and description, clean up code

# %% [markdown]
# #### below is used for testing:

# %%
y, mu, logvar = VAE(16).forward(sample[0])

# %%
y.size()
# Out:
# torch.Size([4, 3, 491, 600])

# %%
mu.size()
# Out:
# torch.Size([4, 54912])

# %%
logvar.size()
# Out:
# torch.Size([4, 54912])

# %% [markdown]
# # Image Preprocessing Class
#
#   Class has been created. Outstanding issues:
#
#   1) Gather image size information to determine best size to conform to
#        $\textit{*this is a testing issue class does not need to be altered}$

# %% [markdown]
# #### Image expansion testing

# %%
image = Image.open('/Users/ianleefmans/Desktop/data/train/part2/part2_images/11/218.jpg') 
if image.mode != 'RGB':
    image = image.convert('RGB')
    
image.show()

# %%
# largest height: 1310
# largest width: 1544

# smallest height: 84
# smallest width: 60

avg_height = 491
avg_width = 600

preprocess = image_process((avg_height, avg_width))

# %%
image = preprocess.expand(image)
image.show()

# %%
image.getpalette
# Out:
# <bound method Image.getpalette of <PIL.Image.Image image mode=RGB size=584x491 at 0x108312790>>

# %%
transform = torchvision.transforms.ToTensor()
image = transform(image)

# %%
image2 = preprocess.uniform_size(image)

# %%
image2.size()
# Out:
# torch.Size([3, 491, 600])

# %%
plt.imshow(torchvision.transforms.ToPILImage(mode='RGB')(image2))

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as f
import torchvision

import os

# takeout part where tokens=list(tok.word_count)
# use doclist instead because tokenizer already makes tokens obviously


class Flatten(nn.Module):
    
    """
        Module which flattens tensor to a 1D tensor
    """
    
    def forward(self, x):
        return x.view(x.size(0), -1)



class Unflatten(nn.Module):
    
    """
        Module which reformats flattened tensor into original format
    """
    
    def __init__(self, x, num_features=None, dimensions=None):
        super(Unflatten, self).__init__()
        
        self.dimensions = dimensions
        self.num_features = num_features
    
    def forward(self, x):
        if self.num_features==None or self.dimensions==None:
            raise Exception("Mandatory argument not assigned")
        
        return x.view(x.size(0), self.num_features*8, self.dimensions[0], self.dimensions[1])




class Fold(nn.Module):
    
    """
        Module which folds 1D tensor (1 X n) resulting in a (2 X n/d) tensor
    """
    
    def forward(self, x):
        return x.view(-1, 2, int(x.size(1)/2))


class Layer(nn.Module):
    """
        Basic block of network: 3x3 convolution, batchnorm, ReLU
    """
    def __init__(self, in_channel, out_channel, stride=0, last_layer=False):
        if last_layer==True:
            
            self.layer = nn.Sequential(
                            nn.Conv2d(in_channel, out_channel, 3, stride=stride),
                            BatchNorm2d(out_channel)
            )
        else:
            
            self.layer = nn.Sequential(
                            nn.Conv2d(in_channel, out_channel, 3, stride = stride),
                            BatchNorm2d(out_channel),
                            nn.ReLU()
            )
        
    def forward(self, x):
        return self.layer(x)
    
    
    
    
class Reverse_Layer(nn.Module):
    """
        Basic block of network: 3x3 transposed convolution, batchnorm, ReLU
    """
    def __init__(self, in_channel, out_channel, stride=0, last_layer=False):
        if last_layer==True:
            
            self.layer = nn.Sequential(
                            ConvTranspose2d(in_channel, out_channel, 3, stride=stride),
                            BatchNorm2d(out_channel)
            )
        else:
            
            self.layer = nn.Sequential(
                            ConvTranspose2d(in_channel, out_channel, 3, stride = stride),
                            BatchNorm2d(out_channel),
                            nn.ReLU()
            )
        
    def forward(self, x):
        return self.layer(x)



class Encoder(nn.Module):
    
    """
        Enocoder Segment of Variational Autoencoder and Backbone of Feature Pyramid Network
    """
    def __init__(self, num_features):
        super(Encoder, self).__init__()
        
        
        self.conv = nn.Conv2d(3, num_features, 7, stride=2)
        self.pool = MaxPool2d(kernel_size=2, return_indices=True)
        self.relu = nn.ReLU()
        self.block1 = nn.Sequential(
                        Layer(num_features, num_features),
                        Layer(num_features, num_features, last_layer=True)
        )
        self.block2 = nn.Sequential(
                        Layer(num_features, num_features*2),
                        Layer(num_features*2, num_features*2, last_layer=True)
        )
        self.block3 = nn.Sequential(
                        Layer(num_features, num_features*4),
                        Layer(num_features*4, num_features*4, last_layer=True)
        )
        self.block4 = nn.Sequential(
                        Layer(num_features, num_features*8),
                        Layer(num_features*8, num_features*8, last_layer=True)
        )
        
        
    
    def forward(self, x):   
        x = self.conv(x)
        prepool_dim = x.size()
        x, idx = self.pool(x)
        x = self.relu(x)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        pic_dim = (x.size(2), x.size(3))
        return x, idx, pic_dim, prepool_dim
        
        
        
        
        
        #x = self.conv1(x)
        #dim1 = x.size()
        #x, idx1 = self.pool(x)
        x = self.relu(x)
        x = self.conv2(x)
        dim2 = x.size()
        x, idx2 = self.pool(x)
        x = self.relu(x)
        x = self.conv3(x)
        dim3 = x.size()
        x, idx3 = self.pool(x)
        x = self.relu(x)
        x = self.conv4(x)
        dim4 = x.size()
        x, idx4 = self.pool(x)
        x = self.relu(x)
        pic_dim = (x.size(2), x.size(3))
        x = self.flatten(x)
        x = self.fold(x)
        idx = [idx1, idx2, idx3, idx4]
        prepool_dim = [dim1, dim2, dim3, dim4]
        return x, idx, pic_dim, prepool_dim
    
    
class Decoder(nn.Module):
    
    def __init__(self, idx, prepool_dim):
        super(Encoder, self).__init__()
        
        self.block1 = nn.Sequential(
                        Layer(num_features*8, num_features*8),
                        Layer(num_features*8, num_features*6, last_layer=True)
        )
        self.block2 = nn.Sequential(
                        Layer(num_features*4, num_features*4),
                        Layer(num_features*4, num_features*2, last_layer=True)
        )
        self.block3 = nn.Sequential(
                        Layer(num_features*2, num_features*2),
                        Layer(num_features*2, num_features, last_layer=True)
        )
        self.block4 = nn.Sequential(
                        Layer(num_features, num_features),
                        Layer(num_features, num_features, last_layer=True)
        )
        self.convT = nn.ConvTranspose2d(3, num_features, 7, stride=2)
        self.unpool = nn.MaxUnpool2d(kernel_size=2)
        self.relu = nn.ReLU()
        self.idx = idx
        self.prepool_dim = prepool_dim
    
    def forward(self, x):
        
        
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.convT(x)
        x = self.unpool(x, self.idx, self.prepool_dim)
        x = self.relu(x)
        return x
        
        
        

class VAE(nn.Module):
    def __init__(self, num_features):
        super(VAE, self).__init__()
        
        self.num_features = num_features
        self.encoder = Encoder(self.num_features)
        self.decoder = Decoder()
        self.flatten = Flatten()
        self.fold = Fold()
        
        
    def reparameterize(self, mu, logvar):
        """
           Function for reparameterization of Variational Autoencoder:
                Samples from a Guassian Distribution
        """
        if self.training:
            std= logvar.mul(0.5).exp_()
            eps1 = std.data.new(std.size()).normal_()
            eps = std.data.new(std.size()).normal_()
            return torch.cat((eps1.mul(std).add_(mu), eps.mul(std).add_(mu)), 1)
        else:
            return torch.cat((mu, mu), 1)


    def forward(self, x):
        x, idx, dimensions, prepool_dim = self.encoder(x)
        x = self.flatten(x)
        x = self.fold(x)
        #print("1,", x.size())
        mu = x[:,0,:]
        logvar = x[:,1,:]
        x = self.reparameterize(mu, logvar)
        #print("2", x.size())
        unflatten = Unflatten(x, dimensions=dimensions, num_features = self.num_features)
        x = unflatten(x)
        #print("3", x.size())
        x = self.Decoder(x, idx, prepool_dim)
        #print("4", x.size())
        
        
        return x, mu, logvar



#### need to figure out what dimensons to pass to unflatten()
